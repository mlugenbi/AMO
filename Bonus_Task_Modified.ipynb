# %% [markdown]
# # Bonus Task

# %% [markdown]
# This notebook contains the solution for the task #3, management of a Virtual Power Plant with stochasticity. <br> <br>
# For reference:
# <br>
# Morales, J.M., Conejo, A.J., Madsen, H., Pinson, P. and Zugno, M., 2013. Integrating renewables in electricity
# markets: operational problems (Vol. 205). Springer Science & Business Media., Chapter 8.

# %%
using JuMP, HiGHS, Plots, DataFrames

# %%
model = Model(HiGHS.Optimizer)
#set_silent(model)
# Out:
# A JuMP Model
# Feasibility problem with:
# Variables: 0
# Model mode: AUTOMATIC
# CachingOptimizer state: EMPTY_OPTIMIZER
# Solver name: HiGHS

# %% [markdown]
# ## Compose Model

# %% [markdown]
# ### Variables and Functions

# %%
T = ["t1", "t2", "t3"] # Time steps
Ω = ["ω1", "ω2", "ω3"] # Scenarios

I = [ "i1"] # power plants

Q = ["q1"] # wind generation units

J = ["j1"] # flexible loads (energy consumers)

K = ["k1"] # storage units (batteries etc.)

λ = Dict("t1" => 20, "t2" => 80, "t3" => 45) # Market price 
π = Dict("ω1" => 0.2, "ω2" => 0.3, "ω3" => 0.5) # probabilities of scenarios

# Cost
EG_coeff = Dict("i1" => 30) # Linear coefficient of power plant cost function’
EG_intersect = Dict("i1" => 50) #’No-load cost’

# Utility
EL_coeff = Dict("j1" => 90) # Linear coeffcient of flexible load utility function 
EL_intersect = Dict("j1" => 5) # Constant term of flexible load utility function 

# Min and max power output of power plant i
PG_min = Dict( "i1" => 1)
PG_max = Dict("i1" => 5)


# Min, max power consumption of flexible load j
PL_min = Dict( "j1" => 0.5)
PL_max = Dict("j1" => 2)
Min_Con = Dict("j1" => 2.5) # Minimum power consumption at the end of t3


# Min, max capacity of storage unit k
ES_max = Dict( "k1" => 1) 
ES_min = Dict( "k1" => 0.2) 
# Intital storage level
ES_0 = Dict( "k1" => 0.4) 
# (Dis)charging power limit
PS_charge_max = Dict( "k1" => 0.3)
PS_discharge_max = Dict( "k1" => 0.5)
PS_eff = Dict("k1" => 0.80) # Efficiency of (dis)charging storage unit k

# Wind generation values for the specific scenarios and time steps
PW_values = Dict(
    ("q1", "ω1", "t1") => 2.5, ("q1", "ω1", "t2") => 4.0, ("q1", "ω1", "t3") => 6.0,
    ("q1", "ω2", "t1") => 6.0, ("q1", "ω2", "t2") => 4.0, ("q1", "ω2", "t3") => 3.5,
    ("q1", "ω3", "t1") => 2.0, ("q1", "ω3", "t2") => 1.1, ("q1", "ω3", "t3") => 1.5
)

# Initialize an empty dictionary for PW
PW = Dict()

# Populate the PW dictionary with values from PW_values
for q in Q
    for ω in Ω
        for t in T
            PW[(q, ω, t)] = PW_values[(q, ω, t)]
        end
    end
end

# %%
# For time steps
function previous_time_period(t, T)
    index = findfirst(isequal(t), T)
    return T[index - 1]
end
# Out:
# previous_time_period (generic function with 1 method)

# %%
@variables(model, begin
        
    PD[T] # power exchanged with the electricity market at time step t
    EG[I,Ω,T] >= 0 # energy generated by power plant i in scenario ω and time step t
    C[I,Ω,T] >= 0  # Cost function for each i, ω, t
    U[J,Ω,T] >= 0 # Utility function for each j, ω, t
  #  PW[Q,Ω,T] >= 0 # energy generated by wind generation unit q in scenario ω and time step t ------------------------> depends on the scenario!!!
    PW_curt[Q,Ω,T] >= 0 # curtailment of energy generated by wind generation unit q in scenario ω and time step t
    PS_discharge[K,Ω,T] >= 0 # power discharged from storage unit k in scenario ω and time step t
    PS_charge[K,Ω,T] >= 0 # power charged to storage unit k in scenario ω and time step t
    ES[K,Ω,T] >= 0 # energy status of storage unit k in scenario ω and time step t
    EL[J,Ω,T] >= 0 # electricity consumed by flexible load j in scenario ω and time step t
    v[I,Ω,T], Bin # binary variable that declares whether or not power plant i is on/off at time step t
    
end)
# Out:
# (1-dimensional DenseAxisArray{VariableRef,1,...} with index sets:
#     Dimension 1, ["t1", "t2", "t3"]
# And data, a 3-element Vector{VariableRef}:
#  PD[t1]
#  PD[t2]
#  PD[t3], 3-dimensional DenseAxisArray{VariableRef,3,...} with index sets:
#     Dimension 1, ["i1"]
#     Dimension 2, ["ω1", "ω2", "ω3"]
#     Dimension 3, ["t1", "t2", "t3"]
# And data, a 1×3×3 Array{VariableRef, 3}:
# [:, :, "t1"] =
#  EG[i1,ω1,t1]  EG[i1,ω2,t1]  EG[i1,ω3,t1]
#
# [:, :, "t2"] =
#  EG[i1,ω1,t2]  EG[i1,ω2,t2]  EG[i1,ω3,t2]
#
# [:, :, "t3"] =
#  EG[i1,ω1,t3]  EG[i1,ω2,t3]  EG[i1,ω3,t3], 3-dimensional DenseAxisArray{VariableRef,3,...} with index sets:
#     Dimension 1, ["i1"]
#     Dimension 2, ["ω1", "ω2", "ω3"]
#     Dimension 3, ["t1", "t2", "t3"]
# And data, a 1×3×3 Array{VariableRef, 3}:
# [:, :, "t1"] =
#  C[i1,ω1,t1]  C[i1,ω2,t1]  C[i1,ω3,t1]
#
# [:, :, "t2"] =
#  C[i1,ω1,t2]  C[i1,ω2,t2]  C[i1,ω3,t2]
#
# [:, :, "t3"] =
#  C[i1,ω1,t3]  C[i1,ω2,t3]  C[i1,ω3,t3], 3-dimensional DenseAxisArray{VariableRef,3,...} with index sets:
#     Dimension 1, ["j1"]
#     Dimension 2, ["ω1", "ω2", "ω3"]
#     Dimension 3, ["t1", "t2", "t3"]
# And data, a 1×3×3 Array{VariableRef, 3}:
# [:, :, "t1"] =
#  U[j1,ω1,t1]  U[j1,ω2,t1]  U[j1,ω3,t1]
#
# [:, :, "t2"] =
#  U[j1,ω1,t2]  U[j1,ω2,t2]  U[j1,ω3,t2]
#
# [:, :, "t3"] =
#  U[j1,ω1,t3]  U[j1,ω2,t3]  U[j1,ω3,t3], 3-dimensional DenseAxisArray{VariableRef,3,...} with index sets:
#     Dimension 1, ["q1"]
#     Dimension 2, ["ω1", "ω2", "ω3"]
#     Dimension 3, ["t1", "t2", "t3"]
# And data, a 1×3×3 Array{VariableRef, 3}:
# [:, :, "t1"] =
#  PW_curt[q1,ω1,t1]  PW_curt[q1,ω2,t1]  PW_curt[q1,ω3,t1]
#
# [:, :, "t2"] =
#  PW_curt[q1,ω1,t2]  PW_curt[q1,ω2,t2]  PW_curt[q1,ω3,t2]
#
# [:, :, "t3"] =
#  PW_curt[q1,ω1,t3]  PW_curt[q1,ω2,t3]  PW_curt[q1,ω3,t3], 3-dimensional DenseAxisArray{VariableRef,3,...} with index sets:
#     Dimension 1, ["k1"]
#     Dimension 2, ["ω1", "ω2", "ω3"]
#     Dimension 3, ["t1", "t2", "t3"]
# And data, a 1×3×3 Array{VariableRef, 3}:
# [:, :, "t1"] =
#  PS_discharge[k1,ω1,t1]  PS_discharge[k1,ω2,t1]  PS_discharge[k1,ω3,t1]
#
# [:, :, "t2"] =
#  PS_discharge[k1,ω1,t2]  PS_discharge[k1,ω2,t2]  PS_discharge[k1,ω3,t2]
#
# [:, :, "t3"] =
#  PS_discharge[k1,ω1,t3]  PS_discharge[k1,ω2,t3]  PS_discharge[k1,ω3,t3], 3-dimensional DenseAxisArray{VariableRef,3,...} with index sets:
#     Dimension 1, ["k1"]
#     Dimension 2, ["ω1", "ω2", "ω3"]
#     Dimension 3, ["t1", "t2", "t3"]
# And data, a 1×3×3 Array{VariableRef, 3}:
# [:, :, "t1"] =
#  PS_charge[k1,ω1,t1]  PS_charge[k1,ω2,t1]  PS_charge[k1,ω3,t1]
#
# [:, :, "t2"] =
#  PS_charge[k1,ω1,t2]  PS_charge[k1,ω2,t2]  PS_charge[k1,ω3,t2]
#
# [:, :, "t3"] =
#  PS_charge[k1,ω1,t3]  PS_charge[k1,ω2,t3]  PS_charge[k1,ω3,t3], 3-dimensional DenseAxisArray{VariableRef,3,...} with index sets:
#     Dimension 1, ["k1"]
#     Dimension 2, ["ω1", "ω2", "ω3"]
#     Dimension 3, ["t1", "t2", "t3"]
# And data, a 1×3×3 Array{VariableRef, 3}:
# [:, :, "t1"] =
#  ES[k1,ω1,t1]  ES[k1,ω2,t1]  ES[k1,ω3,t1]
#
# [:, :, "t2"] =
#  ES[k1,ω1,t2]  ES[k1,ω2,t2]  ES[k1,ω3,t2]
#
# [:, :, "t3"] =
#  ES[k1,ω1,t3]  ES[k1,ω2,t3]  ES[k1,ω3,t3], 3-dimensional DenseAxisArray{VariableRef,3,...} with index sets:
#     Dimension 1, ["j1"]
#     Dimension 2, ["ω1", "ω2", "ω3"]
#     Dimension 3, ["t1", "t2", "t3"]
# And data, a 1×3×3 Array{VariableRef, 3}:
# [:, :, "t1"] =
#  EL[j1,ω1,t1]  EL[j1,ω2,t1]  EL[j1,ω3,t1]
#
# [:, :, "t2"] =
#  EL[j1,ω1,t2]  EL[j1,ω2,t2]  EL[j1,ω3,t2]
#
# [:, :, "t3"] =
#  EL[j1,ω1,t3]  EL[j1,ω2,t3]  EL[j1,ω3,t3], 3-dimensional DenseAxisArray{VariableRef,3,...} with index sets:
#     Dimension 1, ["i1"]
#     Dimension 2, ["ω1", "ω2", "ω3"]
#     Dimension 3, ["t1", "t2", "t3"]
# And data, a 1×3×3 Array{VariableRef, 3}:
# [:, :, "t1"] =
#  v[i1,ω1,t1]  v[i1,ω2,t1]  v[i1,ω3,t1]
#
# [:, :, "t2"] =
#  v[i1,ω1,t2]  v[i1,ω2,t2]  v[i1,ω3,t2]
#
# [:, :, "t3"] =
#  v[i1,ω1,t3]  v[i1,ω2,t3]  v[i1,ω3,t3])

# %% [markdown]
# ### Constraints

# %%
# Energy balance constraint
@constraint(model, E1[ω in Ω, t in T], 
    sum( EG[i,ω,t] for i in I) + (sum( PW[q,ω,t] - PW_curt[q,ω,t] for q in Q) + sum( PS_discharge[k,ω,t] for k in K))
    == sum( EL[j,ω,t] for j in J) + (sum( PS_charge[k,ω,t] for k in K) + PD[t])
)
# Out:
# 2-dimensional DenseAxisArray{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.EqualTo{Float64}}, ScalarShape},2,...} with index sets:
#     Dimension 1, ["ω1", "ω2", "ω3"]
#     Dimension 2, ["t1", "t2", "t3"]
# And data, a 3×3 Matrix{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.EqualTo{Float64}}, ScalarShape}}:
#  E1[ω1,t1] : -PD[t1] + EG[i1,ω1,t1] - PW_curt[q1,ω1,t1] + PS_discharge[k1,ω1,t1] - PS_charge[k1,ω1,t1] - EL[j1,ω1,t1] == -2.5  …  E1[ω1,t3] : -PD[t3] + EG[i1,ω1,t3] - PW_curt[q1,ω1,t3] + PS_discharge[k1,ω1,t3] - PS_charge[k1,ω1,t3] - EL[j1,ω1,t3] == -6
#  E1[ω2,t1] : -PD[t1] + EG[i1,ω2,t1] - PW_curt[q1,ω2,t1] + PS_discharge[k1,ω2,t1] - PS_charge[k1,ω2,t1] - EL[j1,ω2,t1] == -6       E1[ω2,t3] : -PD[t3] + EG[i1,ω2,t3] - PW_curt[q1,ω2,t3] + PS_discharge[k1,ω2,t3] - PS_charge[k1,ω2,t3] - EL[j1,ω2,t3] == -3.5
#  E1[ω3,t1] : -PD[t1] + EG[i1,ω3,t1] - PW_curt[q1,ω3,t1] + PS_discharge[k1,ω3,t1] - PS_charge[k1,ω3,t1] - EL[j1,ω3,t1] == -2       E1[ω3,t3] : -PD[t3] + EG[i1,ω3,t3] - PW_curt[q1,ω3,t3] + PS_discharge[k1,ω3,t3] - PS_charge[k1,ω3,t3] - EL[j1,ω3,t3] == -1.5

# %%
@constraints(model, begin
    # Energy generation constraint of power plants 
    E2[i in I, ω in Ω, t in T], v[i,ω,t] * PG_min[i] <= EG[i,ω,t] 
    E3[i in I, ω in Ω, t in T], EG[i,ω,t] <= v[i,ω,t] * PG_max[i]  

    # Energy demand constraints of flexible loads  
    E4[j in J, ω in Ω, t in T], PL_min[j] <= EL[j,ω,t]  
    E5[j in J, ω in Ω, t in T], EL[j,ω,t] <= PL_max[j]
    E6[j in J, ω in Ω], sum(EL[j,ω,t] for t in T) >= Min_Con[j]

    # Energy level of the battery

    # Consider battery SOC when starting
    E7[k in K, ω in Ω], ES[k,ω,"t1"] == ES_0[k] + (PS_eff[k] * PS_charge[k,ω,"t1"]) - ((1/PS_eff[k]) * PS_discharge[k,ω,"t1"])
    E8[k in K, ω in Ω, t in T[2:end]], ES[k, ω, t] == ES[k, ω, previous_time_period(t, T)] + (PS_eff[k] * PS_charge[k, ω, t]) - ((1/PS_eff[k]) * PS_discharge[k, ω, t])  
    # Max and min SOC
    E9[k in K, ω in Ω, t in T], ES_min[k] <= ES[k, ω, t]
    E10[k in K, ω in Ω, t in T], ES[k, ω, t] <= ES_max[k] 

    # Max and min (dis)charging rates

    E11[k in K, ω in Ω, t in T], 0 <= PS_charge[k, ω, t]
    E12[k in K, ω in Ω, t in T], PS_charge[k, ω, t] <= PS_charge_max[k]  
    E13[k in K, ω in Ω, t in T], 0 <= PS_discharge[k, ω, t]
    E14[k in K, ω in Ω, t in T], PS_discharge[k, ω, t] <= PS_discharge_max[k]
        
    # Power generated by wind power unit in different scenarios and time steps
    cost_function[i in I, ω in Ω, t in T], C[i, ω, t] == EG_coeff[i] * EG[i, ω, t] + EG_intersect[i]
    utility_function[j in J, ω in Ω, t in T], U[j, ω, t] == EL_coeff[j] * (EL[j, ω, t]) + EL_intersect[j]
        
    # Maximum wind curtailment of wind power unit
    E24[q in Q, ω in Ω, t in T], PW_curt[q,ω,t] >= 0
    E25[q in Q, ω in Ω, t in T], PW_curt[q,ω,t] <= PW[q,ω,t] 

end)
# Out:
# (3-dimensional DenseAxisArray{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.LessThan{Float64}}, ScalarShape},3,...} with index sets:
#     Dimension 1, ["i1"]
#     Dimension 2, ["ω1", "ω2", "ω3"]
#     Dimension 3, ["t1", "t2", "t3"]
# And data, a 1×3×3 Array{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.LessThan{Float64}}, ScalarShape}, 3}:
# [:, :, "t1"] =
#  E2[i1,ω1,t1] : -EG[i1,ω1,t1] + v[i1,ω1,t1] <= 0  …  E2[i1,ω3,t1] : -EG[i1,ω3,t1] + v[i1,ω3,t1] <= 0
#
# [:, :, "t2"] =
#  E2[i1,ω1,t2] : -EG[i1,ω1,t2] + v[i1,ω1,t2] <= 0  …  E2[i1,ω3,t2] : -EG[i1,ω3,t2] + v[i1,ω3,t2] <= 0
#
# [:, :, "t3"] =
#  E2[i1,ω1,t3] : -EG[i1,ω1,t3] + v[i1,ω1,t3] <= 0  …  E2[i1,ω3,t3] : -EG[i1,ω3,t3] + v[i1,ω3,t3] <= 0, 3-dimensional DenseAxisArray{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.LessThan{Float64}}, ScalarShape},3,...} with index sets:
#     Dimension 1, ["i1"]
#     Dimension 2, ["ω1", "ω2", "ω3"]
#     Dimension 3, ["t1", "t2", "t3"]
# And data, a 1×3×3 Array{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.LessThan{Float64}}, ScalarShape}, 3}:
# [:, :, "t1"] =
#  E3[i1,ω1,t1] : EG[i1,ω1,t1] - 5 v[i1,ω1,t1] <= 0  …  E3[i1,ω3,t1] : EG[i1,ω3,t1] - 5 v[i1,ω3,t1] <= 0
#
# [:, :, "t2"] =
#  E3[i1,ω1,t2] : EG[i1,ω1,t2] - 5 v[i1,ω1,t2] <= 0  …  E3[i1,ω3,t2] : EG[i1,ω3,t2] - 5 v[i1,ω3,t2] <= 0
#
# [:, :, "t3"] =
#  E3[i1,ω1,t3] : EG[i1,ω1,t3] - 5 v[i1,ω1,t3] <= 0  …  E3[i1,ω3,t3] : EG[i1,ω3,t3] - 5 v[i1,ω3,t3] <= 0, 3-dimensional DenseAxisArray{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.LessThan{Float64}}, ScalarShape},3,...} with index sets:
#     Dimension 1, ["j1"]
#     Dimension 2, ["ω1", "ω2", "ω3"]
#     Dimension 3, ["t1", "t2", "t3"]
# And data, a 1×3×3 Array{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.LessThan{Float64}}, ScalarShape}, 3}:
# [:, :, "t1"] =
#  E4[j1,ω1,t1] : -EL[j1,ω1,t1] <= -0.5  …  E4[j1,ω3,t1] : -EL[j1,ω3,t1] <= -0.5
#
# [:, :, "t2"] =
#  E4[j1,ω1,t2] : -EL[j1,ω1,t2] <= -0.5  …  E4[j1,ω3,t2] : -EL[j1,ω3,t2] <= -0.5
#
# [:, :, "t3"] =
#  E4[j1,ω1,t3] : -EL[j1,ω1,t3] <= -0.5  …  E4[j1,ω3,t3] : -EL[j1,ω3,t3] <= -0.5, 3-dimensional DenseAxisArray{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.LessThan{Float64}}, ScalarShape},3,...} with index sets:
#     Dimension 1, ["j1"]
#     Dimension 2, ["ω1", "ω2", "ω3"]
#     Dimension 3, ["t1", "t2", "t3"]
# And data, a 1×3×3 Array{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.LessThan{Float64}}, ScalarShape}, 3}:
# [:, :, "t1"] =
#  E5[j1,ω1,t1] : EL[j1,ω1,t1] <= 2  …  E5[j1,ω3,t1] : EL[j1,ω3,t1] <= 2
#
# [:, :, "t2"] =
#  E5[j1,ω1,t2] : EL[j1,ω1,t2] <= 2  …  E5[j1,ω3,t2] : EL[j1,ω3,t2] <= 2
#
# [:, :, "t3"] =
#  E5[j1,ω1,t3] : EL[j1,ω1,t3] <= 2  …  E5[j1,ω3,t3] : EL[j1,ω3,t3] <= 2, 2-dimensional DenseAxisArray{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.GreaterThan{Float64}}, ScalarShape},2,...} with index sets:
#     Dimension 1, ["j1"]
#     Dimension 2, ["ω1", "ω2", "ω3"]
# And data, a 1×3 Matrix{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.GreaterThan{Float64}}, ScalarShape}}:
#  E6[j1,ω1] : EL[j1,ω1,t1] + EL[j1,ω1,t2] + EL[j1,ω1,t3] >= 2.5  …  E6[j1,ω3] : EL[j1,ω3,t1] + EL[j1,ω3,t2] + EL[j1,ω3,t3] >= 2.5, 2-dimensional DenseAxisArray{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.EqualTo{Float64}}, ScalarShape},2,...} with index sets:
#     Dimension 1, ["k1"]
#     Dimension 2, ["ω1", "ω2", "ω3"]
# And data, a 1×3 Matrix{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.EqualTo{Float64}}, ScalarShape}}:
#  E7[k1,ω1] : 1.25 PS_discharge[k1,ω1,t1] - 0.8 PS_charge[k1,ω1,t1] + ES[k1,ω1,t1] == 0.4  …  E7[k1,ω3] : 1.25 PS_discharge[k1,ω3,t1] - 0.8 PS_charge[k1,ω3,t1] + ES[k1,ω3,t1] == 0.4, 3-dimensional DenseAxisArray{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.EqualTo{Float64}}, ScalarShape},3,...} with index sets:
#     Dimension 1, ["k1"]
#     Dimension 2, ["ω1", "ω2", "ω3"]
#     Dimension 3, ["t2", "t3"]
# And data, a 1×3×2 Array{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.EqualTo{Float64}}, ScalarShape}, 3}:
# [:, :, "t2"] =
#  E8[k1,ω1,t2] : 1.25 PS_discharge[k1,ω1,t2] - 0.8 PS_charge[k1,ω1,t2] - ES[k1,ω1,t1] + ES[k1,ω1,t2] == 0  …  E8[k1,ω3,t2] : 1.25 PS_discharge[k1,ω3,t2] - 0.8 PS_charge[k1,ω3,t2] - ES[k1,ω3,t1] + ES[k1,ω3,t2] == 0
#
# [:, :, "t3"] =
#  E8[k1,ω1,t3] : 1.25 PS_discharge[k1,ω1,t3] - 0.8 PS_charge[k1,ω1,t3] - ES[k1,ω1,t2] + ES[k1,ω1,t3] == 0  …  E8[k1,ω3,t3] : 1.25 PS_discharge[k1,ω3,t3] - 0.8 PS_charge[k1,ω3,t3] - ES[k1,ω3,t2] + ES[k1,ω3,t3] == 0, 3-dimensional DenseAxisArray{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.LessThan{Float64}}, ScalarShape},3,...} with index sets:
#     Dimension 1, ["k1"]
#     Dimension 2, ["ω1", "ω2", "ω3"]
#     Dimension 3, ["t1", "t2", "t3"]
# And data, a 1×3×3 Array{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.LessThan{Float64}}, ScalarShape}, 3}:
# [:, :, "t1"] =
#  E9[k1,ω1,t1] : -ES[k1,ω1,t1] <= -0.2  …  E9[k1,ω3,t1] : -ES[k1,ω3,t1] <= -0.2
#
# [:, :, "t2"] =
#  E9[k1,ω1,t2] : -ES[k1,ω1,t2] <= -0.2  …  E9[k1,ω3,t2] : -ES[k1,ω3,t2] <= -0.2
#
# [:, :, "t3"] =
#  E9[k1,ω1,t3] : -ES[k1,ω1,t3] <= -0.2  …  E9[k1,ω3,t3] : -ES[k1,ω3,t3] <= -0.2, 3-dimensional DenseAxisArray{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.LessThan{Float64}}, ScalarShape},3,...} with index sets:
#     Dimension 1, ["k1"]
#     Dimension 2, ["ω1", "ω2", "ω3"]
#     Dimension 3, ["t1", "t2", "t3"]
# And data, a 1×3×3 Array{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.LessThan{Float64}}, ScalarShape}, 3}:
# [:, :, "t1"] =
#  E10[k1,ω1,t1] : ES[k1,ω1,t1] <= 1  …  E10[k1,ω3,t1] : ES[k1,ω3,t1] <= 1
#
# [:, :, "t2"] =
#  E10[k1,ω1,t2] : ES[k1,ω1,t2] <= 1  …  E10[k1,ω3,t2] : ES[k1,ω3,t2] <= 1
#
# [:, :, "t3"] =
#  E10[k1,ω1,t3] : ES[k1,ω1,t3] <= 1  …  E10[k1,ω3,t3] : ES[k1,ω3,t3] <= 1, 3-dimensional DenseAxisArray{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.LessThan{Float64}}, ScalarShape},3,...} with index sets:
#     Dimension 1, ["k1"]
#     Dimension 2, ["ω1", "ω2", "ω3"]
#     Dimension 3, ["t1", "t2", "t3"]
# And data, a 1×3×3 Array{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.LessThan{Float64}}, ScalarShape}, 3}:
# [:, :, "t1"] =
#  E11[k1,ω1,t1] : -PS_charge[k1,ω1,t1] <= 0  …  E11[k1,ω3,t1] : -PS_charge[k1,ω3,t1] <= 0
#
# [:, :, "t2"] =
#  E11[k1,ω1,t2] : -PS_charge[k1,ω1,t2] <= 0  …  E11[k1,ω3,t2] : -PS_charge[k1,ω3,t2] <= 0
#
# [:, :, "t3"] =
#  E11[k1,ω1,t3] : -PS_charge[k1,ω1,t3] <= 0  …  E11[k1,ω3,t3] : -PS_charge[k1,ω3,t3] <= 0, 3-dimensional DenseAxisArray{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.LessThan{Float64}}, ScalarShape},3,...} with index sets:
#     Dimension 1, ["k1"]
#     Dimension 2, ["ω1", "ω2", "ω3"]
#     Dimension 3, ["t1", "t2", "t3"]
# And data, a 1×3×3 Array{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.LessThan{Float64}}, ScalarShape}, 3}:
# [:, :, "t1"] =
#  E12[k1,ω1,t1] : PS_charge[k1,ω1,t1] <= 0.3  …  E12[k1,ω3,t1] : PS_charge[k1,ω3,t1] <= 0.3
#
# [:, :, "t2"] =
#  E12[k1,ω1,t2] : PS_charge[k1,ω1,t2] <= 0.3  …  E12[k1,ω3,t2] : PS_charge[k1,ω3,t2] <= 0.3
#
# [:, :, "t3"] =
#  E12[k1,ω1,t3] : PS_charge[k1,ω1,t3] <= 0.3  …  E12[k1,ω3,t3] : PS_charge[k1,ω3,t3] <= 0.3, 3-dimensional DenseAxisArray{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.LessThan{Float64}}, ScalarShape},3,...} with index sets:
#     Dimension 1, ["k1"]
#     Dimension 2, ["ω1", "ω2", "ω3"]
#     Dimension 3, ["t1", "t2", "t3"]
# And data, a 1×3×3 Array{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.LessThan{Float64}}, ScalarShape}, 3}:
# [:, :, "t1"] =
#  E13[k1,ω1,t1] : -PS_discharge[k1,ω1,t1] <= 0  …  E13[k1,ω3,t1] : -PS_discharge[k1,ω3,t1] <= 0
#
# [:, :, "t2"] =
#  E13[k1,ω1,t2] : -PS_discharge[k1,ω1,t2] <= 0  …  E13[k1,ω3,t2] : -PS_discharge[k1,ω3,t2] <= 0
#
# [:, :, "t3"] =
#  E13[k1,ω1,t3] : -PS_discharge[k1,ω1,t3] <= 0  …  E13[k1,ω3,t3] : -PS_discharge[k1,ω3,t3] <= 0, 3-dimensional DenseAxisArray{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.LessThan{Float64}}, ScalarShape},3,...} with index sets:
#     Dimension 1, ["k1"]
#     Dimension 2, ["ω1", "ω2", "ω3"]
#     Dimension 3, ["t1", "t2", "t3"]
# And data, a 1×3×3 Array{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.LessThan{Float64}}, ScalarShape}, 3}:
# [:, :, "t1"] =
#  E14[k1,ω1,t1] : PS_discharge[k1,ω1,t1] <= 0.5  …  E14[k1,ω3,t1] : PS_discharge[k1,ω3,t1] <= 0.5
#
# [:, :, "t2"] =
#  E14[k1,ω1,t2] : PS_discharge[k1,ω1,t2] <= 0.5  …  E14[k1,ω3,t2] : PS_discharge[k1,ω3,t2] <= 0.5
#
# [:, :, "t3"] =
#  E14[k1,ω1,t3] : PS_discharge[k1,ω1,t3] <= 0.5  …  E14[k1,ω3,t3] : PS_discharge[k1,ω3,t3] <= 0.5, 3-dimensional DenseAxisArray{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.EqualTo{Float64}}, ScalarShape},3,...} with index sets:
#     Dimension 1, ["i1"]
#     Dimension 2, ["ω1", "ω2", "ω3"]
#     Dimension 3, ["t1", "t2", "t3"]
# And data, a 1×3×3 Array{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.EqualTo{Float64}}, ScalarShape}, 3}:
# [:, :, "t1"] =
#  cost_function[i1,ω1,t1] : -30 EG[i1,ω1,t1] + C[i1,ω1,t1] == 50  …  cost_function[i1,ω3,t1] : -30 EG[i1,ω3,t1] + C[i1,ω3,t1] == 50
#
# [:, :, "t2"] =
#  cost_function[i1,ω1,t2] : -30 EG[i1,ω1,t2] + C[i1,ω1,t2] == 50  …  cost_function[i1,ω3,t2] : -30 EG[i1,ω3,t2] + C[i1,ω3,t2] == 50
#
# [:, :, "t3"] =
#  cost_function[i1,ω1,t3] : -30 EG[i1,ω1,t3] + C[i1,ω1,t3] == 50  …  cost_function[i1,ω3,t3] : -30 EG[i1,ω3,t3] + C[i1,ω3,t3] == 50, 3-dimensional DenseAxisArray{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.EqualTo{Float64}}, ScalarShape},3,...} with index sets:
#     Dimension 1, ["j1"]
#     Dimension 2, ["ω1", "ω2", "ω3"]
#     Dimension 3, ["t1", "t2", "t3"]
# And data, a 1×3×3 Array{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.EqualTo{Float64}}, ScalarShape}, 3}:
# [:, :, "t1"] =
#  utility_function[j1,ω1,t1] : U[j1,ω1,t1] - 90 EL[j1,ω1,t1] == 5  …  utility_function[j1,ω3,t1] : U[j1,ω3,t1] - 90 EL[j1,ω3,t1] == 5
#
# [:, :, "t2"] =
#  utility_function[j1,ω1,t2] : U[j1,ω1,t2] - 90 EL[j1,ω1,t2] == 5  …  utility_function[j1,ω3,t2] : U[j1,ω3,t2] - 90 EL[j1,ω3,t2] == 5
#
# [:, :, "t3"] =
#  utility_function[j1,ω1,t3] : U[j1,ω1,t3] - 90 EL[j1,ω1,t3] == 5  …  utility_function[j1,ω3,t3] : U[j1,ω3,t3] - 90 EL[j1,ω3,t3] == 5, 3-dimensional DenseAxisArray{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.GreaterThan{Float64}}, ScalarShape},3,...} with index sets:
#     Dimension 1, ["q1"]
#     Dimension 2, ["ω1", "ω2", "ω3"]
#     Dimension 3, ["t1", "t2", "t3"]
# And data, a 1×3×3 Array{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.GreaterThan{Float64}}, ScalarShape}, 3}:
# [:, :, "t1"] =
#  E24[q1,ω1,t1] : PW_curt[q1,ω1,t1] >= 0  …  E24[q1,ω3,t1] : PW_curt[q1,ω3,t1] >= 0
#
# [:, :, "t2"] =
#  E24[q1,ω1,t2] : PW_curt[q1,ω1,t2] >= 0  …  E24[q1,ω3,t2] : PW_curt[q1,ω3,t2] >= 0
#
# [:, :, "t3"] =
#  E24[q1,ω1,t3] : PW_curt[q1,ω1,t3] >= 0  …  E24[q1,ω3,t3] : PW_curt[q1,ω3,t3] >= 0, 3-dimensional DenseAxisArray{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.LessThan{Float64}}, ScalarShape},3,...} with index sets:
#     Dimension 1, ["q1"]
#     Dimension 2, ["ω1", "ω2", "ω3"]
#     Dimension 3, ["t1", "t2", "t3"]
# And data, a 1×3×3 Array{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.LessThan{Float64}}, ScalarShape}, 3}:
# [:, :, "t1"] =
#  E25[q1,ω1,t1] : PW_curt[q1,ω1,t1] <= 2.5  …  E25[q1,ω3,t1] : PW_curt[q1,ω3,t1] <= 2
#
# [:, :, "t2"] =
#  E25[q1,ω1,t2] : PW_curt[q1,ω1,t2] <= 4  …  E25[q1,ω3,t2] : PW_curt[q1,ω3,t2] <= 1.1
#
# [:, :, "t3"] =
#  E25[q1,ω1,t3] : PW_curt[q1,ω1,t3] <= 6  …  E25[q1,ω3,t3] : PW_curt[q1,ω3,t3] <= 1.5)

# %% [markdown]
# ### Optimization Objective

# %%
@objective(model, Max,
    sum(
    ( λ[t] * PD[t]) + sum(π[ω] * ( sum( U[j,ω,t] for j in J) - ( sum( C[i,ω,t] for i in I))) for ω in Ω) for t in T))
# Out:
# 20 PD[t1] + 0.2 U[j1,ω1,t1] - 0.2 C[i1,ω1,t1] + 0.3 U[j1,ω2,t1] - 0.3 C[i1,ω2,t1] + 0.5 U[j1,ω3,t1] - 0.5 C[i1,ω3,t1] + 80 PD[t2] + 0.2 U[j1,ω1,t2] - 0.2 C[i1,ω1,t2] + 0.3 U[j1,ω2,t2] - 0.3 C[i1,ω2,t2] + 0.5 U[j1,ω3,t2] - 0.5 C[i1,ω3,t2] + 45 PD[t3] + 0.2 U[j1,ω1,t3] - 0.2 C[i1,ω1,t3] + 0.3 U[j1,ω2,t3] - 0.3 C[i1,ω2,t3] + 0.5 U[j1,ω3,t3] - 0.5 C[i1,ω3,t3]

# %%
print(model)
# Out:
# $$ \begin{aligned}
# \max\quad & 20 PD_{t1} + 0.2 U_{j1,ω1,t1} - 0.2 C_{i1,ω1,t1} + 0.3 U_{j1,ω2,t1} - 0.3 C_{i1,ω2,t1} + 0.5 U_{j1,ω3,t1} - 0.5 C_{i1,ω3,t1} + 80 PD_{t2} + 0.2 U_{j1,ω1,t2} - 0.2 C_{i1,ω1,t2} + 0.3 U_{j1,ω2,t2} - 0.3 C_{i1,ω2,t2} + 0.5 U_{j1,ω3,t2} - 0.5 C_{i1,ω3,t2} + 45 PD_{t3} + 0.2 U_{j1,ω1,t3} - 0.2 C_{i1,ω1,t3} + 0.3 U_{j1,ω2,t3} - 0.3 C_{i1,ω2,t3} + 0.5 U_{j1,ω3,t3} - 0.5 C_{i1,ω3,t3}\\
# \text{Subject to} \quad & -PD_{t1} + EG_{i1,ω1,t1} - PW\_curt_{q1,ω1,t1} + PS\_discharge_{k1,ω1,t1} - PS\_charge_{k1,ω1,t1} - EL_{j1,ω1,t1} = -2.5\\
#  & -PD_{t1} + EG_{i1,ω2,t1} - PW\_curt_{q1,ω2,t1} + PS\_discharge_{k1,ω2,t1} - PS\_charge_{k1,ω2,t1} - EL_{j1,ω2,t1} = -6\\
#  & -PD_{t1} + EG_{i1,ω3,t1} - PW\_curt_{q1,ω3,t1} + PS\_discharge_{k1,ω3,t1} - PS\_charge_{k1,ω3,t1} - EL_{j1,ω3,t1} = -2\\
#  & -PD_{t2} + EG_{i1,ω1,t2} - PW\_curt_{q1,ω1,t2} + PS\_discharge_{k1,ω1,t2} - PS\_charge_{k1,ω1,t2} - EL_{j1,ω1,t2} = -4\\
#  & -PD_{t2} + EG_{i1,ω2,t2} - PW\_curt_{q1,ω2,t2} + PS\_discharge_{k1,ω2,t2} - PS\_charge_{k1,ω2,t2} - EL_{j1,ω2,t2} = -4\\
#  & -PD_{t2} + EG_{i1,ω3,t2} - PW\_curt_{q1,ω3,t2} + PS\_discharge_{k1,ω3,t2} - PS\_charge_{k1,ω3,t2} - EL_{j1,ω3,t2} = -1.1\\
#  & -PD_{t3} + EG_{i1,ω1,t3} - PW\_curt_{q1,ω1,t3} + PS\_discharge_{k1,ω1,t3} - PS\_charge_{k1,ω1,t3} - EL_{j1,ω1,t3} = -6\\
#  & -PD_{t3} + EG_{i1,ω2,t3} - PW\_curt_{q1,ω2,t3} + PS\_discharge_{k1,ω2,t3} - PS\_charge_{k1,ω2,t3} - EL_{j1,ω2,t3} = -3.5\\
#  & -PD_{t3} + EG_{i1,ω3,t3} - PW\_curt_{q1,ω3,t3} + PS\_discharge_{k1,ω3,t3} - PS\_charge_{k1,ω3,t3} - EL_{j1,ω3,t3} = -1.5\\
#  & 1.25 PS\_discharge_{k1,ω1,t1} - 0.8 PS\_charge_{k1,ω1,t1} + ES_{k1,ω1,t1} = 0.4\\
#  & 1.25 PS\_discharge_{k1,ω2,t1} - 0.8 PS\_charge_{k1,ω2,t1} + ES_{k1,ω2,t1} = 0.4\\
#  & 1.25 PS\_discharge_{k1,ω3,t1} - 0.8 PS\_charge_{k1,ω3,t1} + ES_{k1,ω3,t1} = 0.4\\
#  & 1.25 PS\_discharge_{k1,ω1,t2} - 0.8 PS\_charge_{k1,ω1,t2} - ES_{k1,ω1,t1} + ES_{k1,ω1,t2} = 0\\
#  & 1.25 PS\_discharge_{k1,ω2,t2} - 0.8 PS\_charge_{k1,ω2,t2} - ES_{k1,ω2,t1} + ES_{k1,ω2,t2} = 0\\
#  & 1.25 PS\_discharge_{k1,ω3,t2} - 0.8 PS\_charge_{k1,ω3,t2} - ES_{k1,ω3,t1} + ES_{k1,ω3,t2} = 0\\
#  & 1.25 PS\_discharge_{k1,ω1,t3} - 0.8 PS\_charge_{k1,ω1,t3} - ES_{k1,ω1,t2} + ES_{k1,ω1,t3} = 0\\
#  & 1.25 PS\_discharge_{k1,ω2,t3} - 0.8 PS\_charge_{k1,ω2,t3} - ES_{k1,ω2,t2} + ES_{k1,ω2,t3} = 0\\
#  & 1.25 PS\_discharge_{k1,ω3,t3} - 0.8 PS\_charge_{k1,ω3,t3} - ES_{k1,ω3,t2} + ES_{k1,ω3,t3} = 0\\
#  & -30 EG_{i1,ω1,t1} + C_{i1,ω1,t1} = 50\\
#  & -30 EG_{i1,ω2,t1} + C_{i1,ω2,t1} = 50\\
#  & -30 EG_{i1,ω3,t1} + C_{i1,ω3,t1} = 50\\
#  & -30 EG_{i1,ω1,t2} + C_{i1,ω1,t2} = 50\\
#  & -30 EG_{i1,ω2,t2} + C_{i1,ω2,t2} = 50\\
#  & -30 EG_{i1,ω3,t2} + C_{i1,ω3,t2} = 50\\
#  & -30 EG_{i1,ω1,t3} + C_{i1,ω1,t3} = 50\\
#  & -30 EG_{i1,ω2,t3} + C_{i1,ω2,t3} = 50\\
#  & -30 EG_{i1,ω3,t3} + C_{i1,ω3,t3} = 50\\
#  & U_{j1,ω1,t1} - 90 EL_{j1,ω1,t1} = 5\\
#  & U_{j1,ω2,t1} - 90 EL_{j1,ω2,t1} = 5\\
#  & U_{j1,ω3,t1} - 90 EL_{j1,ω3,t1} = 5\\
#  & U_{j1,ω1,t2} - 90 EL_{j1,ω1,t2} = 5\\
#  & U_{j1,ω2,t2} - 90 EL_{j1,ω2,t2} = 5\\
#  & U_{j1,ω3,t2} - 90 EL_{j1,ω3,t2} = 5\\
#  & U_{j1,ω1,t3} - 90 EL_{j1,ω1,t3} = 5\\
#  & U_{j1,ω2,t3} - 90 EL_{j1,ω2,t3} = 5\\
#  & U_{j1,ω3,t3} - 90 EL_{j1,ω3,t3} = 5\\
#  & EL_{j1,ω1,t1} + EL_{j1,ω1,t2} + EL_{j1,ω1,t3} \geq 2.5\\
#  & EL_{j1,ω2,t1} + EL_{j1,ω2,t2} + EL_{j1,ω2,t3} \geq 2.5\\
#  & EL_{j1,ω3,t1} + EL_{j1,ω3,t2} + EL_{j1,ω3,t3} \geq 2.5\\
#  & PW\_curt_{q1,ω1,t1} \geq 0\\
#  & PW\_curt_{q1,ω2,t1} \geq 0\\
#  & PW\_curt_{q1,ω3,t1} \geq 0\\
#  & PW\_curt_{q1,ω1,t2} \geq 0\\
#  & PW\_curt_{q1,ω2,t2} \geq 0\\
#  & PW\_curt_{q1,ω3,t2} \geq 0\\
#  & PW\_curt_{q1,ω1,t3} \geq 0\\
#  & PW\_curt_{q1,ω2,t3} \geq 0\\
#  & PW\_curt_{q1,ω3,t3} \geq 0\\
#  & -EG_{i1,ω1,t1} + v_{i1,ω1,t1} \leq 0\\
#  & -EG_{i1,ω2,t1} + v_{i1,ω2,t1} \leq 0\\
#  & -EG_{i1,ω3,t1} + v_{i1,ω3,t1} \leq 0\\
#  & -EG_{i1,ω1,t2} + v_{i1,ω1,t2} \leq 0\\
#  & -EG_{i1,ω2,t2} + v_{i1,ω2,t2} \leq 0\\
#  & -EG_{i1,ω3,t2} + v_{i1,ω3,t2} \leq 0\\
#  & -EG_{i1,ω1,t3} + v_{i1,ω1,t3} \leq 0\\
#  & -EG_{i1,ω2,t3} + v_{i1,ω2,t3} \leq 0\\
#  & -EG_{i1,ω3,t3} + v_{i1,ω3,t3} \leq 0\\
#  & EG_{i1,ω1,t1} - 5 v_{i1,ω1,t1} \leq 0\\
#  & EG_{i1,ω2,t1} - 5 v_{i1,ω2,t1} \leq 0\\
#  & EG_{i1,ω3,t1} - 5 v_{i1,ω3,t1} \leq 0\\
#  & EG_{i1,ω1,t2} - 5 v_{i1,ω1,t2} \leq 0\\
#  & EG_{i1,ω2,t2} - 5 v_{i1,ω2,t2} \leq 0\\
#  & EG_{i1,ω3,t2} - 5 v_{i1,ω3,t2} \leq 0\\
#  & EG_{i1,ω1,t3} - 5 v_{i1,ω1,t3} \leq 0\\
#  & EG_{i1,ω2,t3} - 5 v_{i1,ω2,t3} \leq 0\\
#  & EG_{i1,ω3,t3} - 5 v_{i1,ω3,t3} \leq 0\\
#  & -EL_{j1,ω1,t1} \leq -0.5\\
#  & -EL_{j1,ω2,t1} \leq -0.5\\
#  & -EL_{j1,ω3,t1} \leq -0.5\\
#  & -EL_{j1,ω1,t2} \leq -0.5\\
#  & -EL_{j1,ω2,t2} \leq -0.5\\
#  & -EL_{j1,ω3,t2} \leq -0.5\\
#  & -EL_{j1,ω1,t3} \leq -0.5\\
#  & -EL_{j1,ω2,t3} \leq -0.5\\
#  & -EL_{j1,ω3,t3} \leq -0.5\\
#  & EL_{j1,ω1,t1} \leq 2\\
#  & EL_{j1,ω2,t1} \leq 2\\
#  & EL_{j1,ω3,t1} \leq 2\\
#  & EL_{j1,ω1,t2} \leq 2\\
#  & EL_{j1,ω2,t2} \leq 2\\
#  & EL_{j1,ω3,t2} \leq 2\\
#  & EL_{j1,ω1,t3} \leq 2\\
#  & EL_{j1,ω2,t3} \leq 2\\
#  & EL_{j1,ω3,t3} \leq 2\\
#  & -ES_{k1,ω1,t1} \leq -0.2\\
#  & -ES_{k1,ω2,t1} \leq -0.2\\
#  & -ES_{k1,ω3,t1} \leq -0.2\\
#  & -ES_{k1,ω1,t2} \leq -0.2\\
#  & -ES_{k1,ω2,t2} \leq -0.2\\
#  & -ES_{k1,ω3,t2} \leq -0.2\\
#  & -ES_{k1,ω1,t3} \leq -0.2\\
#  & -ES_{k1,ω2,t3} \leq -0.2\\
#  & -ES_{k1,ω3,t3} \leq -0.2\\
#  & ES_{k1,ω1,t1} \leq 1\\
#  & ES_{k1,ω2,t1} \leq 1\\
#  & ES_{k1,ω3,t1} \leq 1\\
#  & ES_{k1,ω1,t2} \leq 1\\
#  & ES_{k1,ω2,t2} \leq 1\\
#  & ES_{k1,ω3,t2} \leq 1\\
#  & ES_{k1,ω1,t3} \leq 1\\
#  & ES_{k1,ω2,t3} \leq 1\\
#  & ES_{k1,ω3,t3} \leq 1\\
#  & -PS\_charge_{k1,ω1,t1} \leq 0\\
#  & -PS\_charge_{k1,ω2,t1} \leq 0\\
#  & -PS\_charge_{k1,ω3,t1} \leq 0\\
#  & -PS\_charge_{k1,ω1,t2} \leq 0\\
#  & -PS\_charge_{k1,ω2,t2} \leq 0\\
#  & -PS\_charge_{k1,ω3,t2} \leq 0\\
#  & -PS\_charge_{k1,ω1,t3} \leq 0\\
#  & -PS\_charge_{k1,ω2,t3} \leq 0\\
#  & -PS\_charge_{k1,ω3,t3} \leq 0\\
#  & PS\_charge_{k1,ω1,t1} \leq 0.3\\
#  & PS\_charge_{k1,ω2,t1} \leq 0.3\\
#  & PS\_charge_{k1,ω3,t1} \leq 0.3\\
#  & PS\_charge_{k1,ω1,t2} \leq 0.3\\
#  & PS\_charge_{k1,ω2,t2} \leq 0.3\\
#  & PS\_charge_{k1,ω3,t2} \leq 0.3\\
#  & PS\_charge_{k1,ω1,t3} \leq 0.3\\
#  & PS\_charge_{k1,ω2,t3} \leq 0.3\\
#  & PS\_charge_{k1,ω3,t3} \leq 0.3\\
#  & -PS\_discharge_{k1,ω1,t1} \leq 0\\
#  & -PS\_discharge_{k1,ω2,t1} \leq 0\\
#  & -PS\_discharge_{k1,ω3,t1} \leq 0\\
#  & -PS\_discharge_{k1,ω1,t2} \leq 0\\
#  & -PS\_discharge_{k1,ω2,t2} \leq 0\\
#  & -PS\_discharge_{k1,ω3,t2} \leq 0\\
#  & -PS\_discharge_{k1,ω1,t3} \leq 0\\
#  & -PS\_discharge_{k1,ω2,t3} \leq 0\\
#  & -PS\_discharge_{k1,ω3,t3} \leq 0\\
#  & PS\_discharge_{k1,ω1,t1} \leq 0.5\\
#  & PS\_discharge_{k1,ω2,t1} \leq 0.5\\
#  & PS\_discharge_{k1,ω3,t1} \leq 0.5\\
#  & PS\_discharge_{k1,ω1,t2} \leq 0.5\\
#  & PS\_discharge_{k1,ω2,t2} \leq 0.5\\
#  & PS\_discharge_{k1,ω3,t2} \leq 0.5\\
#  & PS\_discharge_{k1,ω1,t3} \leq 0.5\\
#  & PS\_discharge_{k1,ω2,t3} \leq 0.5\\
#  & PS\_discharge_{k1,ω3,t3} \leq 0.5\\
#  & PW\_curt_{q1,ω1,t1} \leq 2.5\\
#  & PW\_curt_{q1,ω2,t1} \leq 6\\
#  & PW\_curt_{q1,ω3,t1} \leq 2\\
#  & PW\_curt_{q1,ω1,t2} \leq 4\\
#  & PW\_curt_{q1,ω2,t2} \leq 4\\
#  & PW\_curt_{q1,ω3,t2} \leq 1.1\\
#  & PW\_curt_{q1,ω1,t3} \leq 6\\
#  & PW\_curt_{q1,ω2,t3} \leq 3.5\\
#  & PW\_curt_{q1,ω3,t3} \leq 1.5\\
#  & EG_{i1,ω1,t1} \geq 0\\
#  & EG_{i1,ω2,t1} \geq 0\\
#  & EG_{i1,ω3,t1} \geq 0\\
#  & EG_{i1,ω1,t2} \geq 0\\
#  & EG_{i1,ω2,t2} \geq 0\\
#  & EG_{i1,ω3,t2} \geq 0\\
#  & EG_{i1,ω1,t3} \geq 0\\
#  & EG_{i1,ω2,t3} \geq 0\\
#  & EG_{i1,ω3,t3} \geq 0\\
#  & C_{i1,ω1,t1} \geq 0\\
#  & C_{i1,ω2,t1} \geq 0\\
#  & C_{i1,ω3,t1} \geq 0\\
#  & C_{i1,ω1,t2} \geq 0\\
#  & C_{i1,ω2,t2} \geq 0\\
#  & C_{i1,ω3,t2} \geq 0\\
#  & C_{i1,ω1,t3} \geq 0\\
#  & C_{i1,ω2,t3} \geq 0\\
#  & C_{i1,ω3,t3} \geq 0\\
#  & U_{j1,ω1,t1} \geq 0\\
#  & U_{j1,ω2,t1} \geq 0\\
#  & U_{j1,ω3,t1} \geq 0\\
#  & U_{j1,ω1,t2} \geq 0\\
#  & U_{j1,ω2,t2} \geq 0\\
#  & U_{j1,ω3,t2} \geq 0\\
#  & U_{j1,ω1,t3} \geq 0\\
#  & U_{j1,ω2,t3} \geq 0\\
#  & U_{j1,ω3,t3} \geq 0\\
#  & PW\_curt_{q1,ω1,t1} \geq 0\\
#  & PW\_curt_{q1,ω2,t1} \geq 0\\
#  & PW\_curt_{q1,ω3,t1} \geq 0\\
#  & PW\_curt_{q1,ω1,t2} \geq 0\\
#  & PW\_curt_{q1,ω2,t2} \geq 0\\
#  & PW\_curt_{q1,ω3,t2} \geq 0\\
#  & PW\_curt_{q1,ω1,t3} \geq 0\\
#  & PW\_curt_{q1,ω2,t3} \geq 0\\
#  & PW\_curt_{q1,ω3,t3} \geq 0\\
#  & PS\_discharge_{k1,ω1,t1} \geq 0\\
#  & PS\_discharge_{k1,ω2,t1} \geq 0\\
#  & PS\_discharge_{k1,ω3,t1} \geq 0\\
#  & PS\_discharge_{k1,ω1,t2} \geq 0\\
#  & PS\_discharge_{k1,ω2,t2} \geq 0\\
#  & PS\_discharge_{k1,ω3,t2} \geq 0\\
#  & PS\_discharge_{k1,ω1,t3} \geq 0\\
#  & PS\_discharge_{k1,ω2,t3} \geq 0\\
#  & PS\_discharge_{k1,ω3,t3} \geq 0\\
#  & PS\_charge_{k1,ω1,t1} \geq 0\\
#  & PS\_charge_{k1,ω2,t1} \geq 0\\
#  & PS\_charge_{k1,ω3,t1} \geq 0\\
#  & PS\_charge_{k1,ω1,t2} \geq 0\\
#  & PS\_charge_{k1,ω2,t2} \geq 0\\
#  & PS\_charge_{k1,ω3,t2} \geq 0\\
#  & PS\_charge_{k1,ω1,t3} \geq 0\\
#  & PS\_charge_{k1,ω2,t3} \geq 0\\
#  & PS\_charge_{k1,ω3,t3} \geq 0\\
#  & ES_{k1,ω1,t1} \geq 0\\
#  & ES_{k1,ω2,t1} \geq 0\\
#  & ES_{k1,ω3,t1} \geq 0\\
#  & ES_{k1,ω1,t2} \geq 0\\
#  & ES_{k1,ω2,t2} \geq 0\\
#  & ES_{k1,ω3,t2} \geq 0\\
#  & ES_{k1,ω1,t3} \geq 0\\
#  & ES_{k1,ω2,t3} \geq 0\\
#  & ES_{k1,ω3,t3} \geq 0\\
#  & EL_{j1,ω1,t1} \geq 0\\
#  & EL_{j1,ω2,t1} \geq 0\\
#  & EL_{j1,ω3,t1} \geq 0\\
#  & EL_{j1,ω1,t2} \geq 0\\
#  & EL_{j1,ω2,t2} \geq 0\\
#  & EL_{j1,ω3,t2} \geq 0\\
#  & EL_{j1,ω1,t3} \geq 0\\
#  & EL_{j1,ω2,t3} \geq 0\\
#  & EL_{j1,ω3,t3} \geq 0\\
#  & v_{i1,ω1,t1} \in \{0, 1\}\\
#  & v_{i1,ω2,t1} \in \{0, 1\}\\
#  & v_{i1,ω3,t1} \in \{0, 1\}\\
#  & v_{i1,ω1,t2} \in \{0, 1\}\\
#  & v_{i1,ω2,t2} \in \{0, 1\}\\
#  & v_{i1,ω3,t2} \in \{0, 1\}\\
#  & v_{i1,ω1,t3} \in \{0, 1\}\\
#  & v_{i1,ω2,t3} \in \{0, 1\}\\
#  & v_{i1,ω3,t3} \in \{0, 1\}\\
# \end{aligned} $$

# %%
optimize!(model)
# Out:
# Running HiGHS 1.6.0: Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 39 rows, 66 cols, 132 nonzeros
# 30 rows, 57 cols, 150 nonzeros
# 30 rows, 57 cols, 150 nonzeros
#
# Solving MIP model with:
#    30 rows
#    57 cols (9 binary, 0 integer, 0 implied int., 48 continuous)
#    150 nonzeros
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
#      Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   956.56          -inf                 inf        0      0      0         0     0.0s
#  R       0       0         0   0.00%   779.008         611.66            27.36%        0      0      0        20     0.0s
#
# 11.1% inactive integer columns, restarting
# Model after restart has 29 rows, 56 cols (8 bin., 0 int., 0 impl., 48 cont.), and 143 nonzeros
#
#          0       0         0   0.00%   779.008         611.66            27.36%        0      0      0        20     0.0s
#  R       0       0         0   0.00%   779.008         730.41075          6.65%        0      0      0        23     0.0s
#
# 12.5% inactive integer columns, restarting
# Model after restart has 28 rows, 55 cols (7 bin., 0 int., 0 impl., 48 cont.), and 136 nonzeros
#
#          0       0         0   0.00%   779.008         730.41075          6.65%        0      0      0        23     0.0s
#          0       0         0   0.00%   779.008         730.41075          6.65%        0      0      0        26     0.0s
#  C       0       0         0   0.00%   778.0760364     775.6605           0.31%       91      8      0        44     0.0s
#
# 57.1% inactive integer columns, restarting
# Model after restart has 23 rows, 50 cols (3 bin., 0 int., 0 impl., 47 cont.), and 115 nonzeros
#
#          0       0         0   0.00%   778.0760364     775.6605           0.31%        5      0      0        76     0.0s
#          0       0         0   0.00%   778.0760364     775.6605           0.31%        5      4      0        84     0.0s
#  L       0       0         0   0.00%   777.1605        777.1605           0.00%       34      7      0        91     0.0s
#
# Solving report
#   Status            Optimal
#   Primal bound      777.1605
#   Dual bound        777.1605
#   Gap               0% (tolerance: 0.01%)
#   Solution status   feasible
#                     777.1605 (objective)
#                     0 (bound viol.)
#                     1.33226762955e-15 (int. viol.)
#                     0 (row viol.)
#   Timing            0.04 (total)
#                     0.00 (presolve)
#                     0.00 (postsolve)
#   Nodes             1
#   LP iterations     97 (total)
#                     0 (strong br.)
#                     25 (separation)
#                     38 (heuristics)

# %%
termination_status(model)
# Out:
# OPTIMAL::TerminationStatusCode = 1

# %%
objective_value(model)
# Out:
# 777.1605

# %%
value.(PW_curt)
# Out:
# 3-dimensional DenseAxisArray{Float64,3,...} with index sets:
#     Dimension 1, ["q1"]
#     Dimension 2, ["ω1", "ω2", "ω3"]
#     Dimension 3, ["t1", "t2", "t3"]
# And data, a 1×3×3 Array{Float64, 3}:
# [:, :, "t1"] =
#  0.0  2.5  0.0
#
# [:, :, "t2"] =
#  0.0  0.0  0.0
#
# [:, :, "t3"] =
#  0.0  0.0  0.0

# %%
value.(PD)
# Out:
# 1-dimensional DenseAxisArray{Float64,1,...} with index sets:
#     Dimension 1, ["t1", "t2", "t3"]
# And data, a 3-element Vector{Float64}:
#  1.2000000000000008
#  5.952
#  4.5

# %%
value.(ES)
# Out:
# 3-dimensional DenseAxisArray{Float64,3,...} with index sets:
#     Dimension 1, ["k1"]
#     Dimension 2, ["ω1", "ω2", "ω3"]
#     Dimension 3, ["t1", "t2", "t3"]
# And data, a 1×3×3 Array{Float64, 3}:
# [:, :, "t1"] =
#  0.64  0.64  0.64
#
# [:, :, "t2"] =
#  0.825  0.2  0.2
#
# [:, :, "t3"] =
#  0.2  0.2  0.2

# %%
value.(EL)
# Out:
# 3-dimensional DenseAxisArray{Float64,3,...} with index sets:
#     Dimension 1, ["j1"]
#     Dimension 2, ["ω1", "ω2", "ω3"]
#     Dimension 3, ["t1", "t2", "t3"]
# And data, a 1×3×3 Array{Float64, 3}:
# [:, :, "t1"] =
#  2.0  2.0  2.0
#
# [:, :, "t2"] =
#  2.0  2.0  0.5
#
# [:, :, "t3"] =
#  2.0  2.0  2.0
