# %% [markdown]
# # Bonus Task

# %% [markdown]
# This notebook contains the solution for the task #3, management of a Virtual Power Plant with stochasticity. <br> <br>
# For reference:
# <br>
# Morales, J.M., Conejo, A.J., Madsen, H., Pinson, P. and Zugno, M., 2013. Integrating renewables in electricity
# markets: operational problems (Vol. 205). Springer Science & Business Media., Chapter 8.

# %%
using JuMP, HiGHS, Plots, DataFrames

# %%
model = Model(HiGHS.Optimizer)
#set_silent(model)
# Out:
# A JuMP Model
# Feasibility problem with:
# Variables: 0
# Model mode: AUTOMATIC
# CachingOptimizer state: EMPTY_OPTIMIZER
# Solver name: HiGHS

# %% [markdown]
# ## Compose Model

# %% [markdown]
# ### Variables and Functions

# %%
T = ["t1", "t2", "t3"] # Time steps
Ω = ["ω1", "ω2", "ω3"] # Scenarios

I = [ "i1"] # power plants

Q = ["q1"] # wind generation units

J = ["j1"] # flexible loads (energy consumers)

K = ["k1"] # storage units (batteries etc.)

λ = Dict("t1" => 20, "t2" => 80, "t3" => 45) # Market price --> check
π = Dict("ω1" => 0.2, "ω2" => 0.3, "ω3" => 0.5) # probabilities of scenarios


#aG = 5 #’Quadratic coefficient of GT cost function’ /5/
bG = 10 # ’Linear coefficient of GT cost function’ /10/
cG = 50 #’No-load cost’ /50/

#aL = -30 #’Quadratic coefficient of GF utility function’ /-30/
bL = 50 #’Linear coeffcient of GF utility function’ /150/
cL = 5 #’Constant term of gear factory utility function’ /5/


# Define your PW_values dictionary
PW_values = Dict(
    ("q1", "ω1", "t1") => 2.5, ("q1", "ω1", "t2") => 4.0, ("q1", "ω1", "t3") => 6.0,
    ("q1", "ω2", "t1") => 6.0, ("q1", "ω2", "t2") => 4.0, ("q1", "ω2", "t3") => 3.5,
    ("q1", "ω3", "t1") => 2.0, ("q1", "ω3", "t2") => 1.1, ("q1", "ω3", "t3") => 1.5
)

# Initialize an empty dictionary for PW
PW = Dict()

# Populate the PW dictionary with values from PW_values
for q in Q
    for ω in Ω
        for t in T
            PW[(q, ω, t)] = PW_values[(q, ω, t)]
        end
    end
end

# %%
# For time steps
function previous_time_period(t, T)
    index = findfirst(isequal(t), T)
    return T[index - 1]
end
# Out:
# previous_time_period (generic function with 1 method)

# %%
@variables(model, begin
        
    PD[T] # power exchanged with the electricity market at time step t
    EG_i[I,Ω,T] >= 0 # energy generated by power plant i in scenario ω and time step t
    #EG_j[J,Ω,T] >= 0 # energy consumed by flexbile load j in scenario ω and time step t
    #C[I] # flexbile costs per unit of electricity generated by power plant i 
    C[I,Ω,T] >= 0  # Cost variable for each i, ω, t
    #U[J] # price per unit of energy bought by flexbile load j
    U[J,Ω,T] >= 0
  #  PW[Q,Ω,T] >= 0 # energy generated by wind generation unit q in scenario ω and time step t ------------------------> depends on the scenario!!!
    PW_curt[Q,Ω,T] >= 0 # curtailment of energy generated by wind generation unit q in scenario ω and time step t
    P_discharge_S[K,Ω,T] >= 0 # power discharged from storage unit k in scenario ω and time step t
    P_charge_S[K,Ω,T] >= 0 # power charged to storage unit k in scenario ω and time step t
    ES[K,Ω,T] >= 0 # energy status of storage unit k in scenario ω and time step t
    EL[J,Ω,T] >= 0 # electricity consumed by flexible load j in scenario ω and time step t
    v[I,Ω,T], Bin # binary variable that declares whether or not power plant i is on/off at time step t
    
end)
# Out:
# (1-dimensional DenseAxisArray{VariableRef,1,...} with index sets:
#     Dimension 1, ["t1", "t2", "t3"]
# And data, a 3-element Vector{VariableRef}:
#  PD[t1]
#  PD[t2]
#  PD[t3], 3-dimensional DenseAxisArray{VariableRef,3,...} with index sets:
#     Dimension 1, ["i1"]
#     Dimension 2, ["ω1", "ω2", "ω3"]
#     Dimension 3, ["t1", "t2", "t3"]
# And data, a 1×3×3 Array{VariableRef, 3}:
# [:, :, "t1"] =
#  EG_i[i1,ω1,t1]  EG_i[i1,ω2,t1]  EG_i[i1,ω3,t1]
#
# [:, :, "t2"] =
#  EG_i[i1,ω1,t2]  EG_i[i1,ω2,t2]  EG_i[i1,ω3,t2]
#
# [:, :, "t3"] =
#  EG_i[i1,ω1,t3]  EG_i[i1,ω2,t3]  EG_i[i1,ω3,t3], 3-dimensional DenseAxisArray{VariableRef,3,...} with index sets:
#     Dimension 1, ["i1"]
#     Dimension 2, ["ω1", "ω2", "ω3"]
#     Dimension 3, ["t1", "t2", "t3"]
# And data, a 1×3×3 Array{VariableRef, 3}:
# [:, :, "t1"] =
#  C[i1,ω1,t1]  C[i1,ω2,t1]  C[i1,ω3,t1]
#
# [:, :, "t2"] =
#  C[i1,ω1,t2]  C[i1,ω2,t2]  C[i1,ω3,t2]
#
# [:, :, "t3"] =
#  C[i1,ω1,t3]  C[i1,ω2,t3]  C[i1,ω3,t3], 3-dimensional DenseAxisArray{VariableRef,3,...} with index sets:
#     Dimension 1, ["j1"]
#     Dimension 2, ["ω1", "ω2", "ω3"]
#     Dimension 3, ["t1", "t2", "t3"]
# And data, a 1×3×3 Array{VariableRef, 3}:
# [:, :, "t1"] =
#  U[j1,ω1,t1]  U[j1,ω2,t1]  U[j1,ω3,t1]
#
# [:, :, "t2"] =
#  U[j1,ω1,t2]  U[j1,ω2,t2]  U[j1,ω3,t2]
#
# [:, :, "t3"] =
#  U[j1,ω1,t3]  U[j1,ω2,t3]  U[j1,ω3,t3], 3-dimensional DenseAxisArray{VariableRef,3,...} with index sets:
#     Dimension 1, ["q1"]
#     Dimension 2, ["ω1", "ω2", "ω3"]
#     Dimension 3, ["t1", "t2", "t3"]
# And data, a 1×3×3 Array{VariableRef, 3}:
# [:, :, "t1"] =
#  PW_curt[q1,ω1,t1]  PW_curt[q1,ω2,t1]  PW_curt[q1,ω3,t1]
#
# [:, :, "t2"] =
#  PW_curt[q1,ω1,t2]  PW_curt[q1,ω2,t2]  PW_curt[q1,ω3,t2]
#
# [:, :, "t3"] =
#  PW_curt[q1,ω1,t3]  PW_curt[q1,ω2,t3]  PW_curt[q1,ω3,t3], 3-dimensional DenseAxisArray{VariableRef,3,...} with index sets:
#     Dimension 1, ["k1"]
#     Dimension 2, ["ω1", "ω2", "ω3"]
#     Dimension 3, ["t1", "t2", "t3"]
# And data, a 1×3×3 Array{VariableRef, 3}:
# [:, :, "t1"] =
#  P_discharge_S[k1,ω1,t1]  P_discharge_S[k1,ω2,t1]  P_discharge_S[k1,ω3,t1]
#
# [:, :, "t2"] =
#  P_discharge_S[k1,ω1,t2]  P_discharge_S[k1,ω2,t2]  P_discharge_S[k1,ω3,t2]
#
# [:, :, "t3"] =
#  P_discharge_S[k1,ω1,t3]  P_discharge_S[k1,ω2,t3]  P_discharge_S[k1,ω3,t3], 3-dimensional DenseAxisArray{VariableRef,3,...} with index sets:
#     Dimension 1, ["k1"]
#     Dimension 2, ["ω1", "ω2", "ω3"]
#     Dimension 3, ["t1", "t2", "t3"]
# And data, a 1×3×3 Array{VariableRef, 3}:
# [:, :, "t1"] =
#  P_charge_S[k1,ω1,t1]  P_charge_S[k1,ω2,t1]  P_charge_S[k1,ω3,t1]
#
# [:, :, "t2"] =
#  P_charge_S[k1,ω1,t2]  P_charge_S[k1,ω2,t2]  P_charge_S[k1,ω3,t2]
#
# [:, :, "t3"] =
#  P_charge_S[k1,ω1,t3]  P_charge_S[k1,ω2,t3]  P_charge_S[k1,ω3,t3], 3-dimensional DenseAxisArray{VariableRef,3,...} with index sets:
#     Dimension 1, ["k1"]
#     Dimension 2, ["ω1", "ω2", "ω3"]
#     Dimension 3, ["t1", "t2", "t3"]
# And data, a 1×3×3 Array{VariableRef, 3}:
# [:, :, "t1"] =
#  ES[k1,ω1,t1]  ES[k1,ω2,t1]  ES[k1,ω3,t1]
#
# [:, :, "t2"] =
#  ES[k1,ω1,t2]  ES[k1,ω2,t2]  ES[k1,ω3,t2]
#
# [:, :, "t3"] =
#  ES[k1,ω1,t3]  ES[k1,ω2,t3]  ES[k1,ω3,t3], 3-dimensional DenseAxisArray{VariableRef,3,...} with index sets:
#     Dimension 1, ["j1"]
#     Dimension 2, ["ω1", "ω2", "ω3"]
#     Dimension 3, ["t1", "t2", "t3"]
# And data, a 1×3×3 Array{VariableRef, 3}:
# [:, :, "t1"] =
#  EL[j1,ω1,t1]  EL[j1,ω2,t1]  EL[j1,ω3,t1]
#
# [:, :, "t2"] =
#  EL[j1,ω1,t2]  EL[j1,ω2,t2]  EL[j1,ω3,t2]
#
# [:, :, "t3"] =
#  EL[j1,ω1,t3]  EL[j1,ω2,t3]  EL[j1,ω3,t3], 3-dimensional DenseAxisArray{VariableRef,3,...} with index sets:
#     Dimension 1, ["i1"]
#     Dimension 2, ["ω1", "ω2", "ω3"]
#     Dimension 3, ["t1", "t2", "t3"]
# And data, a 1×3×3 Array{VariableRef, 3}:
# [:, :, "t1"] =
#  v[i1,ω1,t1]  v[i1,ω2,t1]  v[i1,ω3,t1]
#
# [:, :, "t2"] =
#  v[i1,ω1,t2]  v[i1,ω2,t2]  v[i1,ω3,t2]
#
# [:, :, "t3"] =
#  v[i1,ω1,t3]  v[i1,ω2,t3]  v[i1,ω3,t3])

# %% [markdown]
# ### Constraints

# %%
# Energy balance constraint
@constraint(model, E1[ω in Ω, t in T], 
    sum( EG_i[i,ω,t] for i in I) + (sum( PW[q,ω,t] - PW_curt[q,ω,t] for q in Q) + sum( P_discharge_S[k,ω,t] for k in K))
    == sum( EL[j,ω,t] for j in J) + (sum( P_charge_S[k,ω,t] for k in K) + PD[t])
)
# Out:
# 2-dimensional DenseAxisArray{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.EqualTo{Float64}}, ScalarShape},2,...} with index sets:
#     Dimension 1, ["ω1", "ω2", "ω3"]
#     Dimension 2, ["t1", "t2", "t3"]
# And data, a 3×3 Matrix{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.EqualTo{Float64}}, ScalarShape}}:
#  E1[ω1,t1] : -PD[t1] + EG_i[i1,ω1,t1] - PW_curt[q1,ω1,t1] + P_discharge_S[k1,ω1,t1] - P_charge_S[k1,ω1,t1] - EL[j1,ω1,t1] == -2.5  …  E1[ω1,t3] : -PD[t3] + EG_i[i1,ω1,t3] - PW_curt[q1,ω1,t3] + P_discharge_S[k1,ω1,t3] - P_charge_S[k1,ω1,t3] - EL[j1,ω1,t3] == -6
#  E1[ω2,t1] : -PD[t1] + EG_i[i1,ω2,t1] - PW_curt[q1,ω2,t1] + P_discharge_S[k1,ω2,t1] - P_charge_S[k1,ω2,t1] - EL[j1,ω2,t1] == -6       E1[ω2,t3] : -PD[t3] + EG_i[i1,ω2,t3] - PW_curt[q1,ω2,t3] + P_discharge_S[k1,ω2,t3] - P_charge_S[k1,ω2,t3] - EL[j1,ω2,t3] == -3.5
#  E1[ω3,t1] : -PD[t1] + EG_i[i1,ω3,t1] - PW_curt[q1,ω3,t1] + P_discharge_S[k1,ω3,t1] - P_charge_S[k1,ω3,t1] - EL[j1,ω3,t1] == -2       E1[ω3,t3] : -PD[t3] + EG_i[i1,ω3,t3] - PW_curt[q1,ω3,t3] + P_discharge_S[k1,ω3,t3] - P_charge_S[k1,ω3,t3] - EL[j1,ω3,t3] == -1.5

# %%
@constraints(model, begin
    # Energy generation constraint of power plants --> min = 1, max = 5
    E2[i in I, ω in Ω, t in T], v[i,ω,t] * 1 <= EG_i[i,ω,t] 
    E3[i in I, ω in Ω, t in T], EG_i[i,ω,t] <= v[i,ω,t] * 5  

    # Energy demand constraints of flexible loads --> min = 0.5, max = 2 (EL in book), at least 2.5 over all 3 periods  
    E4[j in J, ω in Ω, t in T], 0.5 <= EL[j,ω,t]  
    E5[j in J, ω in Ω, t in T], EL[j,ω,t] <= 2
    E6[j in J, ω in Ω], sum(EL[j,ω,t] for t in T) >= 2.5

    # Energy level of the battery

    # Consider battery SOC when starting
    E7[k in K, ω in Ω], ES[k,ω,"t1"] == 0.4 + P_charge_S[k,ω,"t1"] - P_discharge_S[k,ω,"t1"]
    E8[k in K, ω in Ω, t in T[2:end]], ES[k, ω, t] == ES[k, ω, previous_time_period(t, T)] + P_charge_S[k, ω, t] - P_discharge_S[k, ω, t]
    # Max and min SOC
    E9[k in K, ω in Ω, t in T], 0.2 <= ES[k, ω, t]
    E10[k in K, ω in Ω, t in T], ES[k, ω, t] <= 1 

    # Max and min (dis)charging rates

    E11[k in K, ω in Ω, t in T], 0 <= P_charge_S[k, ω, t]
    E12[k in K, ω in Ω, t in T], P_charge_S[k, ω, t] <= 0.3  
    E13[k in K, ω in Ω, t in T], 0 <= P_discharge_S[k, ω, t]
    E14[k in K, ω in Ω, t in T], P_discharge_S[k, ω, t] <= 0.5
        
    # Power generated by wind power unit in different scenarios and time steps
    cost_function[i in I, ω in Ω, t in T], C[i, ω, t] == bG * EG_i[i, ω, t] + cG
    utility_function[j in J, ω in Ω, t in T], U[j, ω, t] == bL * (EL[j, ω, t]) + cL
        
    # Maximum wind curtailment of wind power unit
    E24[q in Q, ω in Ω, t in T], PW_curt[q,ω,t] >= 0
    E25[q in Q, ω in Ω, t in T], PW_curt[q,ω,t] <= PW[q,ω,t] 

end)
# Out:
# (3-dimensional DenseAxisArray{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.LessThan{Float64}}, ScalarShape},3,...} with index sets:
#     Dimension 1, ["i1"]
#     Dimension 2, ["ω1", "ω2", "ω3"]
#     Dimension 3, ["t1", "t2", "t3"]
# And data, a 1×3×3 Array{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.LessThan{Float64}}, ScalarShape}, 3}:
# [:, :, "t1"] =
#  E2[i1,ω1,t1] : -EG_i[i1,ω1,t1] + v[i1,ω1,t1] <= 0  …  E2[i1,ω3,t1] : -EG_i[i1,ω3,t1] + v[i1,ω3,t1] <= 0
#
# [:, :, "t2"] =
#  E2[i1,ω1,t2] : -EG_i[i1,ω1,t2] + v[i1,ω1,t2] <= 0  …  E2[i1,ω3,t2] : -EG_i[i1,ω3,t2] + v[i1,ω3,t2] <= 0
#
# [:, :, "t3"] =
#  E2[i1,ω1,t3] : -EG_i[i1,ω1,t3] + v[i1,ω1,t3] <= 0  …  E2[i1,ω3,t3] : -EG_i[i1,ω3,t3] + v[i1,ω3,t3] <= 0, 3-dimensional DenseAxisArray{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.LessThan{Float64}}, ScalarShape},3,...} with index sets:
#     Dimension 1, ["i1"]
#     Dimension 2, ["ω1", "ω2", "ω3"]
#     Dimension 3, ["t1", "t2", "t3"]
# And data, a 1×3×3 Array{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.LessThan{Float64}}, ScalarShape}, 3}:
# [:, :, "t1"] =
#  E3[i1,ω1,t1] : EG_i[i1,ω1,t1] - 5 v[i1,ω1,t1] <= 0  …  E3[i1,ω3,t1] : EG_i[i1,ω3,t1] - 5 v[i1,ω3,t1] <= 0
#
# [:, :, "t2"] =
#  E3[i1,ω1,t2] : EG_i[i1,ω1,t2] - 5 v[i1,ω1,t2] <= 0  …  E3[i1,ω3,t2] : EG_i[i1,ω3,t2] - 5 v[i1,ω3,t2] <= 0
#
# [:, :, "t3"] =
#  E3[i1,ω1,t3] : EG_i[i1,ω1,t3] - 5 v[i1,ω1,t3] <= 0  …  E3[i1,ω3,t3] : EG_i[i1,ω3,t3] - 5 v[i1,ω3,t3] <= 0, 3-dimensional DenseAxisArray{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.LessThan{Float64}}, ScalarShape},3,...} with index sets:
#     Dimension 1, ["j1"]
#     Dimension 2, ["ω1", "ω2", "ω3"]
#     Dimension 3, ["t1", "t2", "t3"]
# And data, a 1×3×3 Array{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.LessThan{Float64}}, ScalarShape}, 3}:
# [:, :, "t1"] =
#  E4[j1,ω1,t1] : -EL[j1,ω1,t1] <= -0.5  …  E4[j1,ω3,t1] : -EL[j1,ω3,t1] <= -0.5
#
# [:, :, "t2"] =
#  E4[j1,ω1,t2] : -EL[j1,ω1,t2] <= -0.5  …  E4[j1,ω3,t2] : -EL[j1,ω3,t2] <= -0.5
#
# [:, :, "t3"] =
#  E4[j1,ω1,t3] : -EL[j1,ω1,t3] <= -0.5  …  E4[j1,ω3,t3] : -EL[j1,ω3,t3] <= -0.5, 3-dimensional DenseAxisArray{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.LessThan{Float64}}, ScalarShape},3,...} with index sets:
#     Dimension 1, ["j1"]
#     Dimension 2, ["ω1", "ω2", "ω3"]
#     Dimension 3, ["t1", "t2", "t3"]
# And data, a 1×3×3 Array{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.LessThan{Float64}}, ScalarShape}, 3}:
# [:, :, "t1"] =
#  E5[j1,ω1,t1] : EL[j1,ω1,t1] <= 2  …  E5[j1,ω3,t1] : EL[j1,ω3,t1] <= 2
#
# [:, :, "t2"] =
#  E5[j1,ω1,t2] : EL[j1,ω1,t2] <= 2  …  E5[j1,ω3,t2] : EL[j1,ω3,t2] <= 2
#
# [:, :, "t3"] =
#  E5[j1,ω1,t3] : EL[j1,ω1,t3] <= 2  …  E5[j1,ω3,t3] : EL[j1,ω3,t3] <= 2, 2-dimensional DenseAxisArray{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.GreaterThan{Float64}}, ScalarShape},2,...} with index sets:
#     Dimension 1, ["j1"]
#     Dimension 2, ["ω1", "ω2", "ω3"]
# And data, a 1×3 Matrix{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.GreaterThan{Float64}}, ScalarShape}}:
#  E6[j1,ω1] : EL[j1,ω1,t1] + EL[j1,ω1,t2] + EL[j1,ω1,t3] >= 2.5  …  E6[j1,ω3] : EL[j1,ω3,t1] + EL[j1,ω3,t2] + EL[j1,ω3,t3] >= 2.5, 2-dimensional DenseAxisArray{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.EqualTo{Float64}}, ScalarShape},2,...} with index sets:
#     Dimension 1, ["k1"]
#     Dimension 2, ["ω1", "ω2", "ω3"]
# And data, a 1×3 Matrix{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.EqualTo{Float64}}, ScalarShape}}:
#  E7[k1,ω1] : P_discharge_S[k1,ω1,t1] - P_charge_S[k1,ω1,t1] + ES[k1,ω1,t1] == 0.4  …  E7[k1,ω3] : P_discharge_S[k1,ω3,t1] - P_charge_S[k1,ω3,t1] + ES[k1,ω3,t1] == 0.4, 3-dimensional DenseAxisArray{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.EqualTo{Float64}}, ScalarShape},3,...} with index sets:
#     Dimension 1, ["k1"]
#     Dimension 2, ["ω1", "ω2", "ω3"]
#     Dimension 3, ["t2", "t3"]
# And data, a 1×3×2 Array{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.EqualTo{Float64}}, ScalarShape}, 3}:
# [:, :, "t2"] =
#  E8[k1,ω1,t2] : P_discharge_S[k1,ω1,t2] - P_charge_S[k1,ω1,t2] - ES[k1,ω1,t1] + ES[k1,ω1,t2] == 0  …  E8[k1,ω3,t2] : P_discharge_S[k1,ω3,t2] - P_charge_S[k1,ω3,t2] - ES[k1,ω3,t1] + ES[k1,ω3,t2] == 0
#
# [:, :, "t3"] =
#  E8[k1,ω1,t3] : P_discharge_S[k1,ω1,t3] - P_charge_S[k1,ω1,t3] - ES[k1,ω1,t2] + ES[k1,ω1,t3] == 0  …  E8[k1,ω3,t3] : P_discharge_S[k1,ω3,t3] - P_charge_S[k1,ω3,t3] - ES[k1,ω3,t2] + ES[k1,ω3,t3] == 0, 3-dimensional DenseAxisArray{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.LessThan{Float64}}, ScalarShape},3,...} with index sets:
#     Dimension 1, ["k1"]
#     Dimension 2, ["ω1", "ω2", "ω3"]
#     Dimension 3, ["t1", "t2", "t3"]
# And data, a 1×3×3 Array{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.LessThan{Float64}}, ScalarShape}, 3}:
# [:, :, "t1"] =
#  E9[k1,ω1,t1] : -ES[k1,ω1,t1] <= -0.2  …  E9[k1,ω3,t1] : -ES[k1,ω3,t1] <= -0.2
#
# [:, :, "t2"] =
#  E9[k1,ω1,t2] : -ES[k1,ω1,t2] <= -0.2  …  E9[k1,ω3,t2] : -ES[k1,ω3,t2] <= -0.2
#
# [:, :, "t3"] =
#  E9[k1,ω1,t3] : -ES[k1,ω1,t3] <= -0.2  …  E9[k1,ω3,t3] : -ES[k1,ω3,t3] <= -0.2, 3-dimensional DenseAxisArray{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.LessThan{Float64}}, ScalarShape},3,...} with index sets:
#     Dimension 1, ["k1"]
#     Dimension 2, ["ω1", "ω2", "ω3"]
#     Dimension 3, ["t1", "t2", "t3"]
# And data, a 1×3×3 Array{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.LessThan{Float64}}, ScalarShape}, 3}:
# [:, :, "t1"] =
#  E10[k1,ω1,t1] : ES[k1,ω1,t1] <= 1  …  E10[k1,ω3,t1] : ES[k1,ω3,t1] <= 1
#
# [:, :, "t2"] =
#  E10[k1,ω1,t2] : ES[k1,ω1,t2] <= 1  …  E10[k1,ω3,t2] : ES[k1,ω3,t2] <= 1
#
# [:, :, "t3"] =
#  E10[k1,ω1,t3] : ES[k1,ω1,t3] <= 1  …  E10[k1,ω3,t3] : ES[k1,ω3,t3] <= 1, 3-dimensional DenseAxisArray{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.LessThan{Float64}}, ScalarShape},3,...} with index sets:
#     Dimension 1, ["k1"]
#     Dimension 2, ["ω1", "ω2", "ω3"]
#     Dimension 3, ["t1", "t2", "t3"]
# And data, a 1×3×3 Array{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.LessThan{Float64}}, ScalarShape}, 3}:
# [:, :, "t1"] =
#  E11[k1,ω1,t1] : -P_charge_S[k1,ω1,t1] <= 0  …  E11[k1,ω3,t1] : -P_charge_S[k1,ω3,t1] <= 0
#
# [:, :, "t2"] =
#  E11[k1,ω1,t2] : -P_charge_S[k1,ω1,t2] <= 0  …  E11[k1,ω3,t2] : -P_charge_S[k1,ω3,t2] <= 0
#
# [:, :, "t3"] =
#  E11[k1,ω1,t3] : -P_charge_S[k1,ω1,t3] <= 0  …  E11[k1,ω3,t3] : -P_charge_S[k1,ω3,t3] <= 0, 3-dimensional DenseAxisArray{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.LessThan{Float64}}, ScalarShape},3,...} with index sets:
#     Dimension 1, ["k1"]
#     Dimension 2, ["ω1", "ω2", "ω3"]
#     Dimension 3, ["t1", "t2", "t3"]
# And data, a 1×3×3 Array{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.LessThan{Float64}}, ScalarShape}, 3}:
# [:, :, "t1"] =
#  E12[k1,ω1,t1] : P_charge_S[k1,ω1,t1] <= 0.3  …  E12[k1,ω3,t1] : P_charge_S[k1,ω3,t1] <= 0.3
#
# [:, :, "t2"] =
#  E12[k1,ω1,t2] : P_charge_S[k1,ω1,t2] <= 0.3  …  E12[k1,ω3,t2] : P_charge_S[k1,ω3,t2] <= 0.3
#
# [:, :, "t3"] =
#  E12[k1,ω1,t3] : P_charge_S[k1,ω1,t3] <= 0.3  …  E12[k1,ω3,t3] : P_charge_S[k1,ω3,t3] <= 0.3, 3-dimensional DenseAxisArray{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.LessThan{Float64}}, ScalarShape},3,...} with index sets:
#     Dimension 1, ["k1"]
#     Dimension 2, ["ω1", "ω2", "ω3"]
#     Dimension 3, ["t1", "t2", "t3"]
# And data, a 1×3×3 Array{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.LessThan{Float64}}, ScalarShape}, 3}:
# [:, :, "t1"] =
#  E13[k1,ω1,t1] : -P_discharge_S[k1,ω1,t1] <= 0  …  E13[k1,ω3,t1] : -P_discharge_S[k1,ω3,t1] <= 0
#
# [:, :, "t2"] =
#  E13[k1,ω1,t2] : -P_discharge_S[k1,ω1,t2] <= 0  …  E13[k1,ω3,t2] : -P_discharge_S[k1,ω3,t2] <= 0
#
# [:, :, "t3"] =
#  E13[k1,ω1,t3] : -P_discharge_S[k1,ω1,t3] <= 0  …  E13[k1,ω3,t3] : -P_discharge_S[k1,ω3,t3] <= 0, 3-dimensional DenseAxisArray{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.LessThan{Float64}}, ScalarShape},3,...} with index sets:
#     Dimension 1, ["k1"]
#     Dimension 2, ["ω1", "ω2", "ω3"]
#     Dimension 3, ["t1", "t2", "t3"]
# And data, a 1×3×3 Array{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.LessThan{Float64}}, ScalarShape}, 3}:
# [:, :, "t1"] =
#  E14[k1,ω1,t1] : P_discharge_S[k1,ω1,t1] <= 0.5  …  E14[k1,ω3,t1] : P_discharge_S[k1,ω3,t1] <= 0.5
#
# [:, :, "t2"] =
#  E14[k1,ω1,t2] : P_discharge_S[k1,ω1,t2] <= 0.5  …  E14[k1,ω3,t2] : P_discharge_S[k1,ω3,t2] <= 0.5
#
# [:, :, "t3"] =
#  E14[k1,ω1,t3] : P_discharge_S[k1,ω1,t3] <= 0.5  …  E14[k1,ω3,t3] : P_discharge_S[k1,ω3,t3] <= 0.5, 3-dimensional DenseAxisArray{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.EqualTo{Float64}}, ScalarShape},3,...} with index sets:
#     Dimension 1, ["i1"]
#     Dimension 2, ["ω1", "ω2", "ω3"]
#     Dimension 3, ["t1", "t2", "t3"]
# And data, a 1×3×3 Array{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.EqualTo{Float64}}, ScalarShape}, 3}:
# [:, :, "t1"] =
#  cost_function[i1,ω1,t1] : -10 EG_i[i1,ω1,t1] + C[i1,ω1,t1] == 50  …  cost_function[i1,ω3,t1] : -10 EG_i[i1,ω3,t1] + C[i1,ω3,t1] == 50
#
# [:, :, "t2"] =
#  cost_function[i1,ω1,t2] : -10 EG_i[i1,ω1,t2] + C[i1,ω1,t2] == 50  …  cost_function[i1,ω3,t2] : -10 EG_i[i1,ω3,t2] + C[i1,ω3,t2] == 50
#
# [:, :, "t3"] =
#  cost_function[i1,ω1,t3] : -10 EG_i[i1,ω1,t3] + C[i1,ω1,t3] == 50  …  cost_function[i1,ω3,t3] : -10 EG_i[i1,ω3,t3] + C[i1,ω3,t3] == 50, 3-dimensional DenseAxisArray{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.EqualTo{Float64}}, ScalarShape},3,...} with index sets:
#     Dimension 1, ["j1"]
#     Dimension 2, ["ω1", "ω2", "ω3"]
#     Dimension 3, ["t1", "t2", "t3"]
# And data, a 1×3×3 Array{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.EqualTo{Float64}}, ScalarShape}, 3}:
# [:, :, "t1"] =
#  utility_function[j1,ω1,t1] : U[j1,ω1,t1] - 50 EL[j1,ω1,t1] == 5  …  utility_function[j1,ω3,t1] : U[j1,ω3,t1] - 50 EL[j1,ω3,t1] == 5
#
# [:, :, "t2"] =
#  utility_function[j1,ω1,t2] : U[j1,ω1,t2] - 50 EL[j1,ω1,t2] == 5  …  utility_function[j1,ω3,t2] : U[j1,ω3,t2] - 50 EL[j1,ω3,t2] == 5
#
# [:, :, "t3"] =
#  utility_function[j1,ω1,t3] : U[j1,ω1,t3] - 50 EL[j1,ω1,t3] == 5  …  utility_function[j1,ω3,t3] : U[j1,ω3,t3] - 50 EL[j1,ω3,t3] == 5, 3-dimensional DenseAxisArray{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.GreaterThan{Float64}}, ScalarShape},3,...} with index sets:
#     Dimension 1, ["q1"]
#     Dimension 2, ["ω1", "ω2", "ω3"]
#     Dimension 3, ["t1", "t2", "t3"]
# And data, a 1×3×3 Array{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.GreaterThan{Float64}}, ScalarShape}, 3}:
# [:, :, "t1"] =
#  E24[q1,ω1,t1] : PW_curt[q1,ω1,t1] >= 0  …  E24[q1,ω3,t1] : PW_curt[q1,ω3,t1] >= 0
#
# [:, :, "t2"] =
#  E24[q1,ω1,t2] : PW_curt[q1,ω1,t2] >= 0  …  E24[q1,ω3,t2] : PW_curt[q1,ω3,t2] >= 0
#
# [:, :, "t3"] =
#  E24[q1,ω1,t3] : PW_curt[q1,ω1,t3] >= 0  …  E24[q1,ω3,t3] : PW_curt[q1,ω3,t3] >= 0, 3-dimensional DenseAxisArray{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.LessThan{Float64}}, ScalarShape},3,...} with index sets:
#     Dimension 1, ["q1"]
#     Dimension 2, ["ω1", "ω2", "ω3"]
#     Dimension 3, ["t1", "t2", "t3"]
# And data, a 1×3×3 Array{ConstraintRef{Model, MathOptInterface.ConstraintIndex{MathOptInterface.ScalarAffineFunction{Float64}, MathOptInterface.LessThan{Float64}}, ScalarShape}, 3}:
# [:, :, "t1"] =
#  E25[q1,ω1,t1] : PW_curt[q1,ω1,t1] <= 2.5  …  E25[q1,ω3,t1] : PW_curt[q1,ω3,t1] <= 2
#
# [:, :, "t2"] =
#  E25[q1,ω1,t2] : PW_curt[q1,ω1,t2] <= 4  …  E25[q1,ω3,t2] : PW_curt[q1,ω3,t2] <= 1.1
#
# [:, :, "t3"] =
#  E25[q1,ω1,t3] : PW_curt[q1,ω1,t3] <= 6  …  E25[q1,ω3,t3] : PW_curt[q1,ω3,t3] <= 1.5)

# %% [markdown]
# ### Optimization Objective

# %%
@objective(model, Max,
    sum(
    ( λ[t] * PD[t]) + sum(π[ω] * ( sum( U[j,ω,t] for j in J) - ( sum( C[i,ω,t] for i in I))) for ω in Ω) for t in T))
# Out:
# 20 PD[t1] + 0.2 U[j1,ω1,t1] - 0.2 C[i1,ω1,t1] + 0.3 U[j1,ω2,t1] - 0.3 C[i1,ω2,t1] + 0.5 U[j1,ω3,t1] - 0.5 C[i1,ω3,t1] + 80 PD[t2] + 0.2 U[j1,ω1,t2] - 0.2 C[i1,ω1,t2] + 0.3 U[j1,ω2,t2] - 0.3 C[i1,ω2,t2] + 0.5 U[j1,ω3,t2] - 0.5 C[i1,ω3,t2] + 45 PD[t3] + 0.2 U[j1,ω1,t3] - 0.2 C[i1,ω1,t3] + 0.3 U[j1,ω2,t3] - 0.3 C[i1,ω2,t3] + 0.5 U[j1,ω3,t3] - 0.5 C[i1,ω3,t3]

# %%
print(model)
# Out:
# $$ \begin{aligned}
# \max\quad & 20 PD_{t1} + 0.2 U_{j1,ω1,t1} - 0.2 C_{i1,ω1,t1} + 0.3 U_{j1,ω2,t1} - 0.3 C_{i1,ω2,t1} + 0.5 U_{j1,ω3,t1} - 0.5 C_{i1,ω3,t1} + 80 PD_{t2} + 0.2 U_{j1,ω1,t2} - 0.2 C_{i1,ω1,t2} + 0.3 U_{j1,ω2,t2} - 0.3 C_{i1,ω2,t2} + 0.5 U_{j1,ω3,t2} - 0.5 C_{i1,ω3,t2} + 45 PD_{t3} + 0.2 U_{j1,ω1,t3} - 0.2 C_{i1,ω1,t3} + 0.3 U_{j1,ω2,t3} - 0.3 C_{i1,ω2,t3} + 0.5 U_{j1,ω3,t3} - 0.5 C_{i1,ω3,t3}\\
# \text{Subject to} \quad & -PD_{t1} + EG\_i_{i1,ω1,t1} - PW\_curt_{q1,ω1,t1} + P\_discharge\_S_{k1,ω1,t1} - P\_charge\_S_{k1,ω1,t1} - EL_{j1,ω1,t1} = -2.5\\
#  & -PD_{t1} + EG\_i_{i1,ω2,t1} - PW\_curt_{q1,ω2,t1} + P\_discharge\_S_{k1,ω2,t1} - P\_charge\_S_{k1,ω2,t1} - EL_{j1,ω2,t1} = -6\\
#  & -PD_{t1} + EG\_i_{i1,ω3,t1} - PW\_curt_{q1,ω3,t1} + P\_discharge\_S_{k1,ω3,t1} - P\_charge\_S_{k1,ω3,t1} - EL_{j1,ω3,t1} = -2\\
#  & -PD_{t2} + EG\_i_{i1,ω1,t2} - PW\_curt_{q1,ω1,t2} + P\_discharge\_S_{k1,ω1,t2} - P\_charge\_S_{k1,ω1,t2} - EL_{j1,ω1,t2} = -4\\
#  & -PD_{t2} + EG\_i_{i1,ω2,t2} - PW\_curt_{q1,ω2,t2} + P\_discharge\_S_{k1,ω2,t2} - P\_charge\_S_{k1,ω2,t2} - EL_{j1,ω2,t2} = -4\\
#  & -PD_{t2} + EG\_i_{i1,ω3,t2} - PW\_curt_{q1,ω3,t2} + P\_discharge\_S_{k1,ω3,t2} - P\_charge\_S_{k1,ω3,t2} - EL_{j1,ω3,t2} = -1.1\\
#  & -PD_{t3} + EG\_i_{i1,ω1,t3} - PW\_curt_{q1,ω1,t3} + P\_discharge\_S_{k1,ω1,t3} - P\_charge\_S_{k1,ω1,t3} - EL_{j1,ω1,t3} = -6\\
#  & -PD_{t3} + EG\_i_{i1,ω2,t3} - PW\_curt_{q1,ω2,t3} + P\_discharge\_S_{k1,ω2,t3} - P\_charge\_S_{k1,ω2,t3} - EL_{j1,ω2,t3} = -3.5\\
#  & -PD_{t3} + EG\_i_{i1,ω3,t3} - PW\_curt_{q1,ω3,t3} + P\_discharge\_S_{k1,ω3,t3} - P\_charge\_S_{k1,ω3,t3} - EL_{j1,ω3,t3} = -1.5\\
#  & P\_discharge\_S_{k1,ω1,t1} - P\_charge\_S_{k1,ω1,t1} + ES_{k1,ω1,t1} = 0.4\\
#  & P\_discharge\_S_{k1,ω2,t1} - P\_charge\_S_{k1,ω2,t1} + ES_{k1,ω2,t1} = 0.4\\
#  & P\_discharge\_S_{k1,ω3,t1} - P\_charge\_S_{k1,ω3,t1} + ES_{k1,ω3,t1} = 0.4\\
#  & P\_discharge\_S_{k1,ω1,t2} - P\_charge\_S_{k1,ω1,t2} - ES_{k1,ω1,t1} + ES_{k1,ω1,t2} = 0\\
#  & P\_discharge\_S_{k1,ω2,t2} - P\_charge\_S_{k1,ω2,t2} - ES_{k1,ω2,t1} + ES_{k1,ω2,t2} = 0\\
#  & P\_discharge\_S_{k1,ω3,t2} - P\_charge\_S_{k1,ω3,t2} - ES_{k1,ω3,t1} + ES_{k1,ω3,t2} = 0\\
#  & P\_discharge\_S_{k1,ω1,t3} - P\_charge\_S_{k1,ω1,t3} - ES_{k1,ω1,t2} + ES_{k1,ω1,t3} = 0\\
#  & P\_discharge\_S_{k1,ω2,t3} - P\_charge\_S_{k1,ω2,t3} - ES_{k1,ω2,t2} + ES_{k1,ω2,t3} = 0\\
#  & P\_discharge\_S_{k1,ω3,t3} - P\_charge\_S_{k1,ω3,t3} - ES_{k1,ω3,t2} + ES_{k1,ω3,t3} = 0\\
#  & -10 EG\_i_{i1,ω1,t1} + C_{i1,ω1,t1} = 50\\
#  & -10 EG\_i_{i1,ω2,t1} + C_{i1,ω2,t1} = 50\\
#  & -10 EG\_i_{i1,ω3,t1} + C_{i1,ω3,t1} = 50\\
#  & -10 EG\_i_{i1,ω1,t2} + C_{i1,ω1,t2} = 50\\
#  & -10 EG\_i_{i1,ω2,t2} + C_{i1,ω2,t2} = 50\\
#  & -10 EG\_i_{i1,ω3,t2} + C_{i1,ω3,t2} = 50\\
#  & -10 EG\_i_{i1,ω1,t3} + C_{i1,ω1,t3} = 50\\
#  & -10 EG\_i_{i1,ω2,t3} + C_{i1,ω2,t3} = 50\\
#  & -10 EG\_i_{i1,ω3,t3} + C_{i1,ω3,t3} = 50\\
#  & U_{j1,ω1,t1} - 50 EL_{j1,ω1,t1} = 5\\
#  & U_{j1,ω2,t1} - 50 EL_{j1,ω2,t1} = 5\\
#  & U_{j1,ω3,t1} - 50 EL_{j1,ω3,t1} = 5\\
#  & U_{j1,ω1,t2} - 50 EL_{j1,ω1,t2} = 5\\
#  & U_{j1,ω2,t2} - 50 EL_{j1,ω2,t2} = 5\\
#  & U_{j1,ω3,t2} - 50 EL_{j1,ω3,t2} = 5\\
#  & U_{j1,ω1,t3} - 50 EL_{j1,ω1,t3} = 5\\
#  & U_{j1,ω2,t3} - 50 EL_{j1,ω2,t3} = 5\\
#  & U_{j1,ω3,t3} - 50 EL_{j1,ω3,t3} = 5\\
#  & EL_{j1,ω1,t1} + EL_{j1,ω1,t2} + EL_{j1,ω1,t3} \geq 2.5\\
#  & EL_{j1,ω2,t1} + EL_{j1,ω2,t2} + EL_{j1,ω2,t3} \geq 2.5\\
#  & EL_{j1,ω3,t1} + EL_{j1,ω3,t2} + EL_{j1,ω3,t3} \geq 2.5\\
#  & PW\_curt_{q1,ω1,t1} \geq 0\\
#  & PW\_curt_{q1,ω2,t1} \geq 0\\
#  & PW\_curt_{q1,ω3,t1} \geq 0\\
#  & PW\_curt_{q1,ω1,t2} \geq 0\\
#  & PW\_curt_{q1,ω2,t2} \geq 0\\
#  & PW\_curt_{q1,ω3,t2} \geq 0\\
#  & PW\_curt_{q1,ω1,t3} \geq 0\\
#  & PW\_curt_{q1,ω2,t3} \geq 0\\
#  & PW\_curt_{q1,ω3,t3} \geq 0\\
#  & -EG\_i_{i1,ω1,t1} + v_{i1,ω1,t1} \leq 0\\
#  & -EG\_i_{i1,ω2,t1} + v_{i1,ω2,t1} \leq 0\\
#  & -EG\_i_{i1,ω3,t1} + v_{i1,ω3,t1} \leq 0\\
#  & -EG\_i_{i1,ω1,t2} + v_{i1,ω1,t2} \leq 0\\
#  & -EG\_i_{i1,ω2,t2} + v_{i1,ω2,t2} \leq 0\\
#  & -EG\_i_{i1,ω3,t2} + v_{i1,ω3,t2} \leq 0\\
#  & -EG\_i_{i1,ω1,t3} + v_{i1,ω1,t3} \leq 0\\
#  & -EG\_i_{i1,ω2,t3} + v_{i1,ω2,t3} \leq 0\\
#  & -EG\_i_{i1,ω3,t3} + v_{i1,ω3,t3} \leq 0\\
#  & EG\_i_{i1,ω1,t1} - 5 v_{i1,ω1,t1} \leq 0\\
#  & EG\_i_{i1,ω2,t1} - 5 v_{i1,ω2,t1} \leq 0\\
#  & EG\_i_{i1,ω3,t1} - 5 v_{i1,ω3,t1} \leq 0\\
#  & EG\_i_{i1,ω1,t2} - 5 v_{i1,ω1,t2} \leq 0\\
#  & EG\_i_{i1,ω2,t2} - 5 v_{i1,ω2,t2} \leq 0\\
#  & EG\_i_{i1,ω3,t2} - 5 v_{i1,ω3,t2} \leq 0\\
#  & EG\_i_{i1,ω1,t3} - 5 v_{i1,ω1,t3} \leq 0\\
#  & EG\_i_{i1,ω2,t3} - 5 v_{i1,ω2,t3} \leq 0\\
#  & EG\_i_{i1,ω3,t3} - 5 v_{i1,ω3,t3} \leq 0\\
#  & -EL_{j1,ω1,t1} \leq -0.5\\
#  & -EL_{j1,ω2,t1} \leq -0.5\\
#  & -EL_{j1,ω3,t1} \leq -0.5\\
#  & -EL_{j1,ω1,t2} \leq -0.5\\
#  & -EL_{j1,ω2,t2} \leq -0.5\\
#  & -EL_{j1,ω3,t2} \leq -0.5\\
#  & -EL_{j1,ω1,t3} \leq -0.5\\
#  & -EL_{j1,ω2,t3} \leq -0.5\\
#  & -EL_{j1,ω3,t3} \leq -0.5\\
#  & EL_{j1,ω1,t1} \leq 2\\
#  & EL_{j1,ω2,t1} \leq 2\\
#  & EL_{j1,ω3,t1} \leq 2\\
#  & EL_{j1,ω1,t2} \leq 2\\
#  & EL_{j1,ω2,t2} \leq 2\\
#  & EL_{j1,ω3,t2} \leq 2\\
#  & EL_{j1,ω1,t3} \leq 2\\
#  & EL_{j1,ω2,t3} \leq 2\\
#  & EL_{j1,ω3,t3} \leq 2\\
#  & -ES_{k1,ω1,t1} \leq -0.2\\
#  & -ES_{k1,ω2,t1} \leq -0.2\\
#  & -ES_{k1,ω3,t1} \leq -0.2\\
#  & -ES_{k1,ω1,t2} \leq -0.2\\
#  & -ES_{k1,ω2,t2} \leq -0.2\\
#  & -ES_{k1,ω3,t2} \leq -0.2\\
#  & -ES_{k1,ω1,t3} \leq -0.2\\
#  & -ES_{k1,ω2,t3} \leq -0.2\\
#  & -ES_{k1,ω3,t3} \leq -0.2\\
#  & ES_{k1,ω1,t1} \leq 1\\
#  & ES_{k1,ω2,t1} \leq 1\\
#  & ES_{k1,ω3,t1} \leq 1\\
#  & ES_{k1,ω1,t2} \leq 1\\
#  & ES_{k1,ω2,t2} \leq 1\\
#  & ES_{k1,ω3,t2} \leq 1\\
#  & ES_{k1,ω1,t3} \leq 1\\
#  & ES_{k1,ω2,t3} \leq 1\\
#  & ES_{k1,ω3,t3} \leq 1\\
#  & -P\_charge\_S_{k1,ω1,t1} \leq 0\\
#  & -P\_charge\_S_{k1,ω2,t1} \leq 0\\
#  & -P\_charge\_S_{k1,ω3,t1} \leq 0\\
#  & -P\_charge\_S_{k1,ω1,t2} \leq 0\\
#  & -P\_charge\_S_{k1,ω2,t2} \leq 0\\
#  & -P\_charge\_S_{k1,ω3,t2} \leq 0\\
#  & -P\_charge\_S_{k1,ω1,t3} \leq 0\\
#  & -P\_charge\_S_{k1,ω2,t3} \leq 0\\
#  & -P\_charge\_S_{k1,ω3,t3} \leq 0\\
#  & P\_charge\_S_{k1,ω1,t1} \leq 0.3\\
#  & P\_charge\_S_{k1,ω2,t1} \leq 0.3\\
#  & P\_charge\_S_{k1,ω3,t1} \leq 0.3\\
#  & P\_charge\_S_{k1,ω1,t2} \leq 0.3\\
#  & P\_charge\_S_{k1,ω2,t2} \leq 0.3\\
#  & P\_charge\_S_{k1,ω3,t2} \leq 0.3\\
#  & P\_charge\_S_{k1,ω1,t3} \leq 0.3\\
#  & P\_charge\_S_{k1,ω2,t3} \leq 0.3\\
#  & P\_charge\_S_{k1,ω3,t3} \leq 0.3\\
#  & -P\_discharge\_S_{k1,ω1,t1} \leq 0\\
#  & -P\_discharge\_S_{k1,ω2,t1} \leq 0\\
#  & -P\_discharge\_S_{k1,ω3,t1} \leq 0\\
#  & -P\_discharge\_S_{k1,ω1,t2} \leq 0\\
#  & -P\_discharge\_S_{k1,ω2,t2} \leq 0\\
#  & -P\_discharge\_S_{k1,ω3,t2} \leq 0\\
#  & -P\_discharge\_S_{k1,ω1,t3} \leq 0\\
#  & -P\_discharge\_S_{k1,ω2,t3} \leq 0\\
#  & -P\_discharge\_S_{k1,ω3,t3} \leq 0\\
#  & P\_discharge\_S_{k1,ω1,t1} \leq 0.5\\
#  & P\_discharge\_S_{k1,ω2,t1} \leq 0.5\\
#  & P\_discharge\_S_{k1,ω3,t1} \leq 0.5\\
#  & P\_discharge\_S_{k1,ω1,t2} \leq 0.5\\
#  & P\_discharge\_S_{k1,ω2,t2} \leq 0.5\\
#  & P\_discharge\_S_{k1,ω3,t2} \leq 0.5\\
#  & P\_discharge\_S_{k1,ω1,t3} \leq 0.5\\
#  & P\_discharge\_S_{k1,ω2,t3} \leq 0.5\\
#  & P\_discharge\_S_{k1,ω3,t3} \leq 0.5\\
#  & PW\_curt_{q1,ω1,t1} \leq 2.5\\
#  & PW\_curt_{q1,ω2,t1} \leq 6\\
#  & PW\_curt_{q1,ω3,t1} \leq 2\\
#  & PW\_curt_{q1,ω1,t2} \leq 4\\
#  & PW\_curt_{q1,ω2,t2} \leq 4\\
#  & PW\_curt_{q1,ω3,t2} \leq 1.1\\
#  & PW\_curt_{q1,ω1,t3} \leq 6\\
#  & PW\_curt_{q1,ω2,t3} \leq 3.5\\
#  & PW\_curt_{q1,ω3,t3} \leq 1.5\\
#  & EG\_i_{i1,ω1,t1} \geq 0\\
#  & EG\_i_{i1,ω2,t1} \geq 0\\
#  & EG\_i_{i1,ω3,t1} \geq 0\\
#  & EG\_i_{i1,ω1,t2} \geq 0\\
#  & EG\_i_{i1,ω2,t2} \geq 0\\
#  & EG\_i_{i1,ω3,t2} \geq 0\\
#  & EG\_i_{i1,ω1,t3} \geq 0\\
#  & EG\_i_{i1,ω2,t3} \geq 0\\
#  & EG\_i_{i1,ω3,t3} \geq 0\\
#  & C_{i1,ω1,t1} \geq 0\\
#  & C_{i1,ω2,t1} \geq 0\\
#  & C_{i1,ω3,t1} \geq 0\\
#  & C_{i1,ω1,t2} \geq 0\\
#  & C_{i1,ω2,t2} \geq 0\\
#  & C_{i1,ω3,t2} \geq 0\\
#  & C_{i1,ω1,t3} \geq 0\\
#  & C_{i1,ω2,t3} \geq 0\\
#  & C_{i1,ω3,t3} \geq 0\\
#  & U_{j1,ω1,t1} \geq 0\\
#  & U_{j1,ω2,t1} \geq 0\\
#  & U_{j1,ω3,t1} \geq 0\\
#  & U_{j1,ω1,t2} \geq 0\\
#  & U_{j1,ω2,t2} \geq 0\\
#  & U_{j1,ω3,t2} \geq 0\\
#  & U_{j1,ω1,t3} \geq 0\\
#  & U_{j1,ω2,t3} \geq 0\\
#  & U_{j1,ω3,t3} \geq 0\\
#  & PW\_curt_{q1,ω1,t1} \geq 0\\
#  & PW\_curt_{q1,ω2,t1} \geq 0\\
#  & PW\_curt_{q1,ω3,t1} \geq 0\\
#  & PW\_curt_{q1,ω1,t2} \geq 0\\
#  & PW\_curt_{q1,ω2,t2} \geq 0\\
#  & PW\_curt_{q1,ω3,t2} \geq 0\\
#  & PW\_curt_{q1,ω1,t3} \geq 0\\
#  & PW\_curt_{q1,ω2,t3} \geq 0\\
#  & PW\_curt_{q1,ω3,t3} \geq 0\\
#  & P\_discharge\_S_{k1,ω1,t1} \geq 0\\
#  & P\_discharge\_S_{k1,ω2,t1} \geq 0\\
#  & P\_discharge\_S_{k1,ω3,t1} \geq 0\\
#  & P\_discharge\_S_{k1,ω1,t2} \geq 0\\
#  & P\_discharge\_S_{k1,ω2,t2} \geq 0\\
#  & P\_discharge\_S_{k1,ω3,t2} \geq 0\\
#  & P\_discharge\_S_{k1,ω1,t3} \geq 0\\
#  & P\_discharge\_S_{k1,ω2,t3} \geq 0\\
#  & P\_discharge\_S_{k1,ω3,t3} \geq 0\\
#  & P\_charge\_S_{k1,ω1,t1} \geq 0\\
#  & P\_charge\_S_{k1,ω2,t1} \geq 0\\
#  & P\_charge\_S_{k1,ω3,t1} \geq 0\\
#  & P\_charge\_S_{k1,ω1,t2} \geq 0\\
#  & P\_charge\_S_{k1,ω2,t2} \geq 0\\
#  & P\_charge\_S_{k1,ω3,t2} \geq 0\\
#  & P\_charge\_S_{k1,ω1,t3} \geq 0\\
#  & P\_charge\_S_{k1,ω2,t3} \geq 0\\
#  & P\_charge\_S_{k1,ω3,t3} \geq 0\\
#  & ES_{k1,ω1,t1} \geq 0\\
#  & ES_{k1,ω2,t1} \geq 0\\
#  & ES_{k1,ω3,t1} \geq 0\\
#  & ES_{k1,ω1,t2} \geq 0\\
#  & ES_{k1,ω2,t2} \geq 0\\
#  & ES_{k1,ω3,t2} \geq 0\\
#  & ES_{k1,ω1,t3} \geq 0\\
#  & ES_{k1,ω2,t3} \geq 0\\
#  & ES_{k1,ω3,t3} \geq 0\\
#  & EL_{j1,ω1,t1} \geq 0\\
#  & EL_{j1,ω2,t1} \geq 0\\
#  & EL_{j1,ω3,t1} \geq 0\\
#  & EL_{j1,ω1,t2} \geq 0\\
#  & EL_{j1,ω2,t2} \geq 0\\
#  & EL_{j1,ω3,t2} \geq 0\\
#  & EL_{j1,ω1,t3} \geq 0\\
#  & EL_{j1,ω2,t3} \geq 0\\
#  & EL_{j1,ω3,t3} \geq 0\\
#  & v_{i1,ω1,t1} \in \{0, 1\}\\
#  & v_{i1,ω2,t1} \in \{0, 1\}\\
#  & v_{i1,ω3,t1} \in \{0, 1\}\\
#  & v_{i1,ω1,t2} \in \{0, 1\}\\
#  & v_{i1,ω2,t2} \in \{0, 1\}\\
#  & v_{i1,ω3,t2} \in \{0, 1\}\\
#  & v_{i1,ω1,t3} \in \{0, 1\}\\
#  & v_{i1,ω2,t3} \in \{0, 1\}\\
#  & v_{i1,ω3,t3} \in \{0, 1\}\\
# \end{aligned} $$

# %%
optimize!(model)
# Out:
# Running HiGHS 1.6.0: Copyright (c) 2023 HiGHS under MIT licence terms
# Presolving model
# 39 rows, 66 cols, 132 nonzeros
# 30 rows, 57 cols, 150 nonzeros
# 27 rows, 45 cols, 117 nonzeros
# 27 rows, 45 cols, 117 nonzeros
#
# Solving MIP model with:
#    27 rows
#    45 cols (9 binary, 0 integer, 0 implied int., 36 continuous)
#    117 nonzeros
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
#      Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#          0       0         0   0.00%   927             -inf                 inf        0      0      0         0     0.0s
#  R       0       0         0   0.00%   819.5           672.5             21.86%        0      0      0        18     0.0s
#
# 22.2% inactive integer columns, restarting
# Model after restart has 25 rows, 42 cols (7 bin., 0 int., 0 impl., 35 cont.), and 104 nonzeros
#
#          0       0         0   0.00%   819.5           672.5             21.86%        0      0      0        18     0.0s
#  R       0       0         0   0.00%   819.5           703               16.57%        0      0      0        22     0.0s
#  C       0       0         0   0.00%   819.5           802.5              2.12%       44      7      0        31     0.0s
#  T       0       0         0   0.00%   819.5           819.5              0.00%       44      7      0        31     0.0s
#
# Solving report
#   Status            Optimal
#   Primal bound      819.5
#   Dual bound        819.5
#   Gap               0% (tolerance: 0.01%)
#   Solution status   feasible
#                     819.5 (objective)
#                     0 (bound viol.)
#                     8.881784197e-16 (int. viol.)
#                     0 (row viol.)
#   Timing            0.02 (total)
#                     0.00 (presolve)
#                     0.00 (postsolve)
#   Nodes             1
#   LP iterations     31 (total)
#                     0 (strong br.)
#                     9 (separation)
#                     0 (heuristics)

# %%
termination_status(model)
# Out:
# OPTIMAL::TerminationStatusCode = 1

# %%
objective_value(model)
# Out:
# 819.5

# %%
value.(PW_curt)
# Out:
# 3-dimensional DenseAxisArray{Float64,3,...} with index sets:
#     Dimension 1, ["q1"]
#     Dimension 2, ["ω1", "ω2", "ω3"]
#     Dimension 3, ["t1", "t2", "t3"]
# And data, a 1×3×3 Array{Float64, 3}:
# [:, :, "t1"] =
#  0.0  0.0  0.0
#
# [:, :, "t2"] =
#  0.0  0.0  0.0
#
# [:, :, "t3"] =
#  0.0  0.0  0.0

# %%
value.(PD)
# Out:
# 1-dimensional DenseAxisArray{Float64,1,...} with index sets:
#     Dimension 1, ["t1", "t2", "t3"]
# And data, a 3-element Vector{Float64}:
#  4.7
#  6.1
#  6.0

# %%
value.(ES)
# Out:
# 3-dimensional DenseAxisArray{Float64,3,...} with index sets:
#     Dimension 1, ["k1"]
#     Dimension 2, ["ω1", "ω2", "ω3"]
#     Dimension 3, ["t1", "t2", "t3"]
# And data, a 1×3×3 Array{Float64, 3}:
# [:, :, "t1"] =
#  0.7  0.7  0.7
#
# [:, :, "t2"] =
#  0.2  0.2  0.2
#
# [:, :, "t3"] =
#  0.2  0.2  0.2

# %%
value.(EL)
# Out:
# 3-dimensional DenseAxisArray{Float64,3,...} with index sets:
#     Dimension 1, ["j1"]
#     Dimension 2, ["ω1", "ω2", "ω3"]
#     Dimension 3, ["t1", "t2", "t3"]
# And data, a 1×3×3 Array{Float64, 3}:
# [:, :, "t1"] =
#  2.0  2.0  2.0
#
# [:, :, "t2"] =
#  2.0  2.0  0.5
#
# [:, :, "t3"] =
#  2.0  2.0  0.5
